# %% [markdown]
# # YOLOv5 for License Plate Detection

# %% [markdown]
# ## Dataset: [Car License Plate Detection](https://www.kaggle.com/andrewmvd/car-plate-detection)
# ![](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F793761%2Fc15e812b3ab9aad2c0694a2e1f7548e9%2FUntitled.png?generation=1590981584876269&alt=media)

# %% [markdown]
# ## Repro [YOLOv5](https://github.com/ultralytics/yolov5)

# %%
# Clone YOLOv5 code
# !git clone https://github.com/rkuo2000/yolov5
# %cd yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12560, done.
# remote: Total 12560 (delta 0), reused 0 (delta 0), pack-reused 12560
# Receiving objects: 100% (12560/12560), 12.37 MiB | 26.67 MiB/s, done.
# Resolving deltas: 100% (8577/8577), done.
# /kaggle/working/yolov5

# %%
# !echo "train: Dataset/train/images" > data/alpr.yaml
# !echo "val:   Dataset/train/images" >> data/alpr.yaml

# !echo "nc : 1" >> data/alpr.yaml
# !echo "names: ['license']" >> data/alpr.yaml

# !cat data/alpr.yaml
# Out:
# train: Dataset/train/images
# val:   Dataset/train/images
# nc : 1
# names: ['license']

# %% [markdown]
# ## Prepare Dataset

# %%
import os
import numpy as np
from pathlib import Path
from xml.dom.minidom import parse
from shutil import copyfile

# %%
FILE_ROOT = "/kaggle/input/car-plate-detection/"
IMAGE_PATH = FILE_ROOT + "images"  
ANNOTATIONS_PATH = FILE_ROOT + "annotations"

DATA_ROOT = "Dataset/"
DEST_IMAGES_PATH = "train/images"
DEST_LABELS_PATH = "train/labels"

# %%
# !mkdir -p Dataset/train/labels

# %%
# copy images
# !mkdir -p Dataset/train
# !cp -rf /kaggle/input/car-plate-detection/images Dataset/train

# %%
# !mkdir -p Dataset/val
# !cp -rf /kaggle/input/car-plate-detection/images/Cars1*.png Dataset/val

# %% [markdown]
# ### Convert COCO Annotations to YOLOv5 Labels

# %%
def cord_converter(size, box):
    """
    convert xml annotation to darknet format coordinates
    :param size： [w,h]
    :param box: anchor box coordinates [upper-left x,uppler-left y,lower-right x, lower-right y]
    :return: converted [x,y,w,h]
    """
    x1 = int(box[0])
    y1 = int(box[1])
    x2 = int(box[2])
    y2 = int(box[3])

    dw = np.float32(1. / int(size[0]))
    dh = np.float32(1. / int(size[1]))

    w = x2 - x1
    h = y2 - y1
    x = x1 + (w / 2)
    y = y1 + (h / 2)

    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return [x, y, w, h]
    
def save_file(img_jpg_file_name, size, img_box):
    classes = ['license']
    save_file_name = DATA_ROOT + DEST_LABELS_PATH + '/' + img_jpg_file_name + '.txt'
    print(save_file_name)
    file_path = open(save_file_name, "a+")
    for box in img_box:                  
        #cls_num = classes.index(box[0]) # find class_id
        cls_num = 0
        new_box = cord_converter(size, box[1:]) # convert box coord into YOLO x,y,w,h

        file_path.write(f"{cls_num} {new_box[0]} {new_box[1]} {new_box[2]} {new_box[3]}\n")

    file_path.flush()
    file_path.close()
    
def get_xml_data(file_path, img_xml_file):
    img_path = file_path + '/' + img_xml_file + '.xml'
    print(img_path)

    dom = parse(img_path)
    root = dom.documentElement
    img_name = root.getElementsByTagName("filename")[0].childNodes[0].data
    img_size = root.getElementsByTagName("size")[0]
    objects = root.getElementsByTagName("object")
    img_w = img_size.getElementsByTagName("width")[0].childNodes[0].data
    img_h = img_size.getElementsByTagName("height")[0].childNodes[0].data
    img_c = img_size.getElementsByTagName("depth")[0].childNodes[0].data
    # print("img_name:", img_name)
    # print("image_info:(w,h,c)", img_w, img_h, img_c)
    img_box = []
    for box in objects:
        cls_name = box.getElementsByTagName("name")[0].childNodes[0].data
        x1 = int(box.getElementsByTagName("xmin")[0].childNodes[0].data)
        y1 = int(box.getElementsByTagName("ymin")[0].childNodes[0].data)
        x2 = int(box.getElementsByTagName("xmax")[0].childNodes[0].data)
        y2 = int(box.getElementsByTagName("ymax")[0].childNodes[0].data)
        print("box:(c,xmin,ymin,xmax,ymax)", cls_name, x1, y1, x2, y2)
        img_jpg_file_name = img_xml_file + '.jpg'
        img_box.append([cls_name, x1, y1, x2, y2])
    # print(img_box)
    # test_dataset_box_feature(img_jpg_file_name, img_box)
    save_file(img_xml_file, [img_w, img_h], img_box)

# %%
files = os.listdir(ANNOTATIONS_PATH)
for file in files:
    print("file name: ", file)
    file_xml = file.split(".")
    get_xml_data(ANNOTATIONS_PATH, file_xml[0])
# Out:
# file name:  Cars339.xml
# /kaggle/input/car-plate-detection/annotations/Cars339.xml
# box:(c,xmin,ymin,xmax,ymax) licence 209 135 283 169
# Dataset/train/labels/Cars339.txt
# file name:  Cars13.xml
# /kaggle/input/car-plate-detection/annotations/Cars13.xml
# box:(c,xmin,ymin,xmax,ymax) licence 191 147 242 169
# Dataset/train/labels/Cars13.txt
# file name:  Cars74.xml
# /kaggle/input/car-plate-detection/annotations/Cars74.xml
# box:(c,xmin,ymin,xmax,ymax) licence 115 115 277 153
# Dataset/train/labels/Cars74.txt
# file name:  Cars16.xml
# /kaggle/input/car-plate-detection/annotations/Cars16.xml
# box:(c,xmin,ymin,xmax,ymax) licence 36 175 62 186
# Dataset/train/labels/Cars16.txt
# file name:  Cars291.xml
# /kaggle/input/car-plate-detection/annotations/Cars291.xml
# box:(c,xmin,ymin,xmax,ymax) licence 71 205 215 246
# Dataset/train/labels/Cars291.txt
# file name:  Cars236.xml
# /kaggle/input/car-plate-detection/annotations/Cars236.xml
# box:(c,xmin,ymin,xmax,ymax) licence 223 106 250 119
# Dataset/train/labels/Cars236.txt
# file name:  Cars429.xml
# /kaggle/input/car-plate-detection/annotations/Cars429.xml
# box:(c,xmin,ymin,xmax,ymax) licence 86 166 208 195
# Dataset/train/labels/Cars429.txt
# file name:  Cars132.xml
# /kaggle/input/car-plate-detection/annotations/Cars132.xml
# box:(c,xmin,ymin,xmax,ymax) licence 23 190 56 198
# box:(c,xmin,ymin,xmax,ymax) licence 378 188 400 200
# Dataset/train/labels/Cars132.txt
# file name:  Cars251.xml
# /kaggle/input/car-plate-detection/annotations/Cars251.xml
# box:(c,xmin,ymin,xmax,ymax) licence 136 134 210 153
# Dataset/train/labels/Cars251.txt
# file name:  Cars51.xml
# /kaggle/input/car-plate-detection/annotations/Cars51.xml
# box:(c,xmin,ymin,xmax,ymax) licence 264 141 318 162
# Dataset/train/labels/Cars51.txt
# file name:  Cars165.xml
# /kaggle/input/car-plate-detection/annotations/Cars165.xml
# box:(c,xmin,ymin,xmax,ymax) licence 209 217 293 254
# Dataset/train/labels/Cars165.txt
# file name:  Cars313.xml
# /kaggle/input/car-plate-detection/annotations/Cars313.xml
# box:(c,xmin,ymin,xmax,ymax) licence 176 211 252 246
# Dataset/train/labels/Cars313.txt
# file name:  Cars240.xml
# /kaggle/input/car-plate-detection/annotations/Cars240.xml
# box:(c,xmin,ymin,xmax,ymax) licence 171 116 232 132
# Dataset/train/labels/Cars240.txt
# file name:  Cars201.xml
# /kaggle/input/car-plate-detection/annotations/Cars201.xml
# box:(c,xmin,ymin,xmax,ymax) licence 216 171 367 208
# Dataset/train/labels/Cars201.txt
# file name:  Cars412.xml
# /kaggle/input/car-plate-detection/annotations/Cars412.xml
# box:(c,xmin,ymin,xmax,ymax) licence 221 172 362 202
# Dataset/train/labels/Cars412.txt
# file name:  Cars227.xml
# /kaggle/input/car-plate-detection/annotations/Cars227.xml
# box:(c,xmin,ymin,xmax,ymax) licence 118 199 153 211
# Dataset/train/labels/Cars227.txt
# file name:  Cars145.xml
# /kaggle/input/car-plate-detection/annotations/Cars145.xml
# box:(c,xmin,ymin,xmax,ymax) licence 282 236 422 283
# Dataset/train/labels/Cars145.txt
# file name:  Cars203.xml
# /kaggle/input/car-plate-detection/annotations/Cars203.xml
# box:(c,xmin,ymin,xmax,ymax) licence 116 112 271 165
# Dataset/train/labels/Cars203.txt
# file name:  Cars131.xml
# /kaggle/input/car-plate-detection/annotations/Cars131.xml
# box:(c,xmin,ymin,xmax,ymax) licence 19 29 497 245
# Dataset/train/labels/Cars131.txt
# file name:  Cars423.xml
# /kaggle/input/car-plate-detection/annotations/Cars423.xml
# box:(c,xmin,ymin,xmax,ymax) licence 162 159 283 183
# Dataset/train/labels/Cars423.txt
# file name:  Cars123.xml
# /kaggle/input/car-plate-detection/annotations/Cars123.xml
# box:(c,xmin,ymin,xmax,ymax) licence 159 221 237 242
# Dataset/train/labels/Cars123.txt
# file name:  Cars189.xml
# /kaggle/input/car-plate-detection/annotations/Cars189.xml
# box:(c,xmin,ymin,xmax,ymax) licence 285 241 423 286
# Dataset/train/labels/Cars189.txt
# file name:  Cars175.xml
# /kaggle/input/car-plate-detection/annotations/Cars175.xml
# box:(c,xmin,ymin,xmax,ymax) licence 295 237 456 367
# Dataset/train/labels/Cars175.txt
# file name:  Cars30.xml
# /kaggle/input/car-plate-detection/annotations/Cars30.xml
# box:(c,xmin,ymin,xmax,ymax) licence 155 169 200 182
# Dataset/train/labels/Cars30.txt
# file name:  Cars197.xml
# /kaggle/input/car-plate-detection/annotations/Cars197.xml
# box:(c,xmin,ymin,xmax,ymax) licence 222 176 359 201
# Dataset/train/labels/Cars197.txt
# file name:  Cars99.xml
# /kaggle/input/car-plate-detection/annotations/Cars99.xml
# box:(c,xmin,ymin,xmax,ymax) licence 70 198 262 271
# Dataset/train/labels/Cars99.txt
# file name:  Cars191.xml
# /kaggle/input/car-plate-detection/annotations/Cars191.xml
# box:(c,xmin,ymin,xmax,ymax) licence 96 189 199 217
# Dataset/train/labels/Cars191.txt
# file name:  Cars168.xml
# /kaggle/input/car-plate-detection/annotations/Cars168.xml
# box:(c,xmin,ymin,xmax,ymax) licence 82 95 137 125
# Dataset/train/labels/Cars168.txt
# file name:  Cars239.xml
# /kaggle/input/car-plate-detection/annotations/Cars239.xml
# box:(c,xmin,ymin,xmax,ymax) licence 176 254 326 284
# Dataset/train/labels/Cars239.txt
# file name:  Cars26.xml
# /kaggle/input/car-plate-detection/annotations/Cars26.xml
# box:(c,xmin,ymin,xmax,ymax) licence 258 184 321 213
# Dataset/train/labels/Cars26.txt
# file name:  Cars115.xml
# /kaggle/input/car-plate-detection/annotations/Cars115.xml
# box:(c,xmin,ymin,xmax,ymax) licence 315 287 407 311
# Dataset/train/labels/Cars115.txt
# file name:  Cars119.xml
# /kaggle/input/car-plate-detection/annotations/Cars119.xml
# box:(c,xmin,ymin,xmax,ymax) licence 187 140 217 153
# Dataset/train/labels/Cars119.txt
# file name:  Cars395.xml
# /kaggle/input/car-plate-detection/annotations/Cars395.xml
# box:(c,xmin,ymin,xmax,ymax) licence 241 182 288 205
# Dataset/train/labels/Cars395.txt
# file name:  Cars96.xml
# /kaggle/input/car-plate-detection/annotations/Cars96.xml
# box:(c,xmin,ymin,xmax,ymax) licence 133 126 261 160
# Dataset/train/labels/Cars96.txt
# file name:  Cars231.xml
# /kaggle/input/car-plate-detection/annotations/Cars231.xml
# box:(c,xmin,ymin,xmax,ymax) licence 64 160 133 180
# Dataset/train/labels/Cars231.txt
# file name:  Cars422.xml
# /kaggle/input/car-plate-detection/annotations/Cars422.xml
# box:(c,xmin,ymin,xmax,ymax) licence 159 126 296 182
# Dataset/train/labels/Cars422.txt
# file name:  Cars192.xml
# /kaggle/input/car-plate-detection/annotations/Cars192.xml
# box:(c,xmin,ymin,xmax,ymax) licence 108 150 211 173
# Dataset/train/labels/Cars192.txt
# file name:  Cars389.xml
# /kaggle/input/car-plate-detection/annotations/Cars389.xml
# box:(c,xmin,ymin,xmax,ymax) licence 77 305 222 370
# Dataset/train/labels/Cars389.txt
# file name:  Cars409.xml
# /kaggle/input/car-plate-detection/annotations/Cars409.xml
# box:(c,xmin,ymin,xmax,ymax) licence 116 146 203 168
# Dataset/train/labels/Cars409.txt
# file name:  Cars107.xml
# /kaggle/input/car-plate-detection/annotations/Cars107.xml
# box:(c,xmin,ymin,xmax,ymax) licence 141 113 311 164
# Dataset/train/labels/Cars107.txt
# file name:  Cars147.xml
# /kaggle/input/car-plate-detection/annotations/Cars147.xml
# box:(c,xmin,ymin,xmax,ymax) licence 226 125 420 169
# Dataset/train/labels/Cars147.txt
# file name:  Cars77.xml
# /kaggle/input/car-plate-detection/annotations/Cars77.xml
# box:(c,xmin,ymin,xmax,ymax) licence 229 151 309 178
# Dataset/train/labels/Cars77.txt
# file name:  Cars420.xml
# /kaggle/input/car-plate-detection/annotations/Cars420.xml
# box:(c,xmin,ymin,xmax,ymax) licence 112 186 160 211
# Dataset/train/labels/Cars420.txt
# file name:  Cars196.xml
# /kaggle/input/car-plate-detection/annotations/Cars196.xml
# box:(c,xmin,ymin,xmax,ymax) licence 105 128 130 140
# Dataset/train/labels/Cars196.txt
# file name:  Cars73.xml
# /kaggle/input/car-plate-detection/annotations/Cars73.xml
# box:(c,xmin,ymin,xmax,ymax) licence 119 22 283 69
# Dataset/train/labels/Cars73.txt
# file name:  Cars343.xml
# /kaggle/input/car-plate-detection/annotations/Cars343.xml
# box:(c,xmin,ymin,xmax,ymax) licence 110 186 162 209
# Dataset/train/labels/Cars343.txt
# file name:  Cars3.xml
# /kaggle/input/car-plate-detection/annotations/Cars3.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 128 261 157
# Dataset/train/labels/Cars3.txt
# file name:  Cars295.xml
# /kaggle/input/car-plate-detection/annotations/Cars295.xml
# box:(c,xmin,ymin,xmax,ymax) licence 52 170 73 182
# box:(c,xmin,ymin,xmax,ymax) licence 237 143 271 162
# Dataset/train/labels/Cars295.txt
# file name:  Cars392.xml
# /kaggle/input/car-plate-detection/annotations/Cars392.xml
# box:(c,xmin,ymin,xmax,ymax) licence 144 150 260 209
# Dataset/train/labels/Cars392.txt
# file name:  Cars314.xml
# /kaggle/input/car-plate-detection/annotations/Cars314.xml
# box:(c,xmin,ymin,xmax,ymax) licence 195 149 274 209
# Dataset/train/labels/Cars314.txt
# file name:  Cars261.xml
# /kaggle/input/car-plate-detection/annotations/Cars261.xml
# box:(c,xmin,ymin,xmax,ymax) licence 1 74 464 154
# Dataset/train/labels/Cars261.txt
# file name:  Cars127.xml
# /kaggle/input/car-plate-detection/annotations/Cars127.xml
# box:(c,xmin,ymin,xmax,ymax) licence 360 166 383 181
# Dataset/train/labels/Cars127.txt
# file name:  Cars102.xml
# /kaggle/input/car-plate-detection/annotations/Cars102.xml
# box:(c,xmin,ymin,xmax,ymax) licence 66 147 322 199
# Dataset/train/labels/Cars102.txt
# file name:  Cars384.xml
# /kaggle/input/car-plate-detection/annotations/Cars384.xml
# box:(c,xmin,ymin,xmax,ymax) licence 219 194 271 230
# Dataset/train/labels/Cars384.txt
# file name:  Cars135.xml
# /kaggle/input/car-plate-detection/annotations/Cars135.xml
# box:(c,xmin,ymin,xmax,ymax) licence 260 184 319 211
# Dataset/train/labels/Cars135.txt
# file name:  Cars151.xml
# /kaggle/input/car-plate-detection/annotations/Cars151.xml
# box:(c,xmin,ymin,xmax,ymax) licence 54 135 120 178
# Dataset/train/labels/Cars151.txt
# file name:  Cars124.xml
# /kaggle/input/car-plate-detection/annotations/Cars124.xml
# box:(c,xmin,ymin,xmax,ymax) licence 305 256 320 267
# Dataset/train/labels/Cars124.txt
# file name:  Cars38.xml
# /kaggle/input/car-plate-detection/annotations/Cars38.xml
# box:(c,xmin,ymin,xmax,ymax) licence 168 196 240 231
# Dataset/train/labels/Cars38.txt
# file name:  Cars14.xml
# /kaggle/input/car-plate-detection/annotations/Cars14.xml
# box:(c,xmin,ymin,xmax,ymax) licence 94 118 274 163
# Dataset/train/labels/Cars14.txt
# file name:  Cars425.xml
# /kaggle/input/car-plate-detection/annotations/Cars425.xml
# box:(c,xmin,ymin,xmax,ymax) licence 211 103 301 132
# Dataset/train/labels/Cars425.txt
# file name:  Cars83.xml
# /kaggle/input/car-plate-detection/annotations/Cars83.xml
# box:(c,xmin,ymin,xmax,ymax) licence 251 295 326 341
# Dataset/train/labels/Cars83.txt
# file name:  Cars72.xml
# /kaggle/input/car-plate-detection/annotations/Cars72.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 182 255 208
# Dataset/train/labels/Cars72.txt
# file name:  Cars39.xml
# /kaggle/input/car-plate-detection/annotations/Cars39.xml
# box:(c,xmin,ymin,xmax,ymax) licence 225 180 328 213
# Dataset/train/labels/Cars39.txt
# file name:  Cars267.xml
# /kaggle/input/car-plate-detection/annotations/Cars267.xml
# box:(c,xmin,ymin,xmax,ymax) licence 274 118 343 138
# Dataset/train/labels/Cars267.txt
# file name:  Cars182.xml
# /kaggle/input/car-plate-detection/annotations/Cars182.xml
# box:(c,xmin,ymin,xmax,ymax) licence 168 139 247 159
# Dataset/train/labels/Cars182.txt
# file name:  Cars237.xml
# /kaggle/input/car-plate-detection/annotations/Cars237.xml
# box:(c,xmin,ymin,xmax,ymax) licence 118 148 154 169
# Dataset/train/labels/Cars237.txt
# file name:  Cars40.xml
# /kaggle/input/car-plate-detection/annotations/Cars40.xml
# box:(c,xmin,ymin,xmax,ymax) licence 261 186 317 211
# Dataset/train/labels/Cars40.txt
# file name:  Cars112.xml
# /kaggle/input/car-plate-detection/annotations/Cars112.xml
# box:(c,xmin,ymin,xmax,ymax) licence 49 135 164 191
# Dataset/train/labels/Cars112.txt
# file name:  Cars341.xml
# /kaggle/input/car-plate-detection/annotations/Cars341.xml
# box:(c,xmin,ymin,xmax,ymax) licence 47 161 115 192
# Dataset/train/labels/Cars341.txt
# file name:  Cars373.xml
# /kaggle/input/car-plate-detection/annotations/Cars373.xml
# box:(c,xmin,ymin,xmax,ymax) licence 161 132 264 157
# Dataset/train/labels/Cars373.txt
# file name:  Cars268.xml
# /kaggle/input/car-plate-detection/annotations/Cars268.xml
# box:(c,xmin,ymin,xmax,ymax) licence 213 133 271 168
# Dataset/train/labels/Cars268.txt
# file name:  Cars45.xml
# /kaggle/input/car-plate-detection/annotations/Cars45.xml
# box:(c,xmin,ymin,xmax,ymax) licence 204 103 280 175
# Dataset/train/labels/Cars45.txt
# file name:  Cars417.xml
# /kaggle/input/car-plate-detection/annotations/Cars417.xml
# box:(c,xmin,ymin,xmax,ymax) licence 90 145 273 196
# Dataset/train/labels/Cars417.txt
# file name:  Cars150.xml
# /kaggle/input/car-plate-detection/annotations/Cars150.xml
# box:(c,xmin,ymin,xmax,ymax) licence 122 198 262 232
# Dataset/train/labels/Cars150.txt
# file name:  Cars383.xml
# /kaggle/input/car-plate-detection/annotations/Cars383.xml
# box:(c,xmin,ymin,xmax,ymax) licence 54 216 88 228
# Dataset/train/labels/Cars383.txt
# file name:  Cars375.xml
# /kaggle/input/car-plate-detection/annotations/Cars375.xml
# box:(c,xmin,ymin,xmax,ymax) licence 144 114 300 145
# Dataset/train/labels/Cars375.txt
# file name:  Cars202.xml
# /kaggle/input/car-plate-detection/annotations/Cars202.xml
# box:(c,xmin,ymin,xmax,ymax) licence 197 135 249 159
# Dataset/train/labels/Cars202.txt
# file name:  Cars256.xml
# /kaggle/input/car-plate-detection/annotations/Cars256.xml
# box:(c,xmin,ymin,xmax,ymax) licence 286 175 400 212
# Dataset/train/labels/Cars256.txt
# file name:  Cars342.xml
# /kaggle/input/car-plate-detection/annotations/Cars342.xml
# box:(c,xmin,ymin,xmax,ymax) licence 196 148 253 169
# Dataset/train/labels/Cars342.txt
# file name:  Cars358.xml
# /kaggle/input/car-plate-detection/annotations/Cars358.xml
# box:(c,xmin,ymin,xmax,ymax) licence 44 94 107 107
# box:(c,xmin,ymin,xmax,ymax) licence 296 122 358 135
# Dataset/train/labels/Cars358.txt
# file name:  Cars350.xml
# /kaggle/input/car-plate-detection/annotations/Cars350.xml
# box:(c,xmin,ymin,xmax,ymax) licence 162 179 211 188
# Dataset/train/labels/Cars350.txt
# file name:  Cars353.xml
# /kaggle/input/car-plate-detection/annotations/Cars353.xml
# box:(c,xmin,ymin,xmax,ymax) licence 93 189 201 221
# Dataset/train/labels/Cars353.txt
# file name:  Cars241.xml
# /kaggle/input/car-plate-detection/annotations/Cars241.xml
# box:(c,xmin,ymin,xmax,ymax) licence 126 142 241 199
# Dataset/train/labels/Cars241.txt
# file name:  Cars174.xml
# /kaggle/input/car-plate-detection/annotations/Cars174.xml
# box:(c,xmin,ymin,xmax,ymax) licence 283 159 306 168
# box:(c,xmin,ymin,xmax,ymax) licence 103 150 122 158
# Dataset/train/labels/Cars174.txt
# file name:  Cars28.xml
# /kaggle/input/car-plate-detection/annotations/Cars28.xml
# box:(c,xmin,ymin,xmax,ymax) licence 541 366 598 384
# Dataset/train/labels/Cars28.txt
# file name:  Cars289.xml
# /kaggle/input/car-plate-detection/annotations/Cars289.xml
# box:(c,xmin,ymin,xmax,ymax) licence 163 140 271 173
# Dataset/train/labels/Cars289.txt
# file name:  Cars207.xml
# /kaggle/input/car-plate-detection/annotations/Cars207.xml
# box:(c,xmin,ymin,xmax,ymax) licence 254 229 372 264
# Dataset/train/labels/Cars207.txt
# file name:  Cars255.xml
# /kaggle/input/car-plate-detection/annotations/Cars255.xml
# box:(c,xmin,ymin,xmax,ymax) licence 116 156 273 188
# Dataset/train/labels/Cars255.txt
# file name:  Cars154.xml
# /kaggle/input/car-plate-detection/annotations/Cars154.xml
# box:(c,xmin,ymin,xmax,ymax) licence 70 197 264 265
# Dataset/train/labels/Cars154.txt
# file name:  Cars244.xml
# /kaggle/input/car-plate-detection/annotations/Cars244.xml
# box:(c,xmin,ymin,xmax,ymax) licence 20 87 360 155
# Dataset/train/labels/Cars244.txt
# file name:  Cars400.xml
# /kaggle/input/car-plate-detection/annotations/Cars400.xml
# box:(c,xmin,ymin,xmax,ymax) licence 303 191 340 217
# Dataset/train/labels/Cars400.txt
# file name:  Cars337.xml
# /kaggle/input/car-plate-detection/annotations/Cars337.xml
# box:(c,xmin,ymin,xmax,ymax) licence 119 131 136 154
# Dataset/train/labels/Cars337.txt
# file name:  Cars272.xml
# /kaggle/input/car-plate-detection/annotations/Cars272.xml
# box:(c,xmin,ymin,xmax,ymax) licence 170 81 316 121
# Dataset/train/labels/Cars272.txt
# file name:  Cars302.xml
# /kaggle/input/car-plate-detection/annotations/Cars302.xml
# box:(c,xmin,ymin,xmax,ymax) licence 222 98 425 149
# Dataset/train/labels/Cars302.txt
# file name:  Cars0.xml
# /kaggle/input/car-plate-detection/annotations/Cars0.xml
# box:(c,xmin,ymin,xmax,ymax) licence 226 125 419 173
# Dataset/train/labels/Cars0.txt
# file name:  Cars186.xml
# /kaggle/input/car-plate-detection/annotations/Cars186.xml
# box:(c,xmin,ymin,xmax,ymax) licence 175 152 242 175
# Dataset/train/labels/Cars186.txt
# file name:  Cars249.xml
# /kaggle/input/car-plate-detection/annotations/Cars249.xml
# box:(c,xmin,ymin,xmax,ymax) licence 118 91 149 99
# box:(c,xmin,ymin,xmax,ymax) licence 238 60 269 79
# box:(c,xmin,ymin,xmax,ymax) licence 133 195 161 203
# box:(c,xmin,ymin,xmax,ymax) licence 300 208 354 226
# Dataset/train/labels/Cars249.txt
# file name:  Cars359.xml
# /kaggle/input/car-plate-detection/annotations/Cars359.xml
# box:(c,xmin,ymin,xmax,ymax) licence 228 228 266 240
# Dataset/train/labels/Cars359.txt
# file name:  Cars404.xml
# /kaggle/input/car-plate-detection/annotations/Cars404.xml
# box:(c,xmin,ymin,xmax,ymax) licence 162 208 235 244
# Dataset/train/labels/Cars404.txt
# file name:  Cars12.xml
# /kaggle/input/car-plate-detection/annotations/Cars12.xml
# box:(c,xmin,ymin,xmax,ymax) licence 122 82 277 117
# Dataset/train/labels/Cars12.txt
# file name:  Cars397.xml
# /kaggle/input/car-plate-detection/annotations/Cars397.xml
# box:(c,xmin,ymin,xmax,ymax) licence 144 169 216 212
# Dataset/train/labels/Cars397.txt
# file name:  Cars17.xml
# /kaggle/input/car-plate-detection/annotations/Cars17.xml
# box:(c,xmin,ymin,xmax,ymax) licence 306 188 351 205
# Dataset/train/labels/Cars17.txt
# file name:  Cars307.xml
# /kaggle/input/car-plate-detection/annotations/Cars307.xml
# box:(c,xmin,ymin,xmax,ymax) licence 172 163 437 220
# Dataset/train/labels/Cars307.txt
# file name:  Cars378.xml
# /kaggle/input/car-plate-detection/annotations/Cars378.xml
# box:(c,xmin,ymin,xmax,ymax) licence 118 92 254 137
# Dataset/train/labels/Cars378.txt
# file name:  Cars81.xml
# /kaggle/input/car-plate-detection/annotations/Cars81.xml
# box:(c,xmin,ymin,xmax,ymax) licence 297 100 327 125
# Dataset/train/labels/Cars81.txt
# file name:  Cars427.xml
# /kaggle/input/car-plate-detection/annotations/Cars427.xml
# box:(c,xmin,ymin,xmax,ymax) licence 236 193 375 228
# Dataset/train/labels/Cars427.txt
# file name:  Cars7.xml
# /kaggle/input/car-plate-detection/annotations/Cars7.xml
# box:(c,xmin,ymin,xmax,ymax) licence 166 141 206 154
# Dataset/train/labels/Cars7.txt
# file name:  Cars364.xml
# /kaggle/input/car-plate-detection/annotations/Cars364.xml
# box:(c,xmin,ymin,xmax,ymax) licence 61 140 115 167
# Dataset/train/labels/Cars364.txt
# file name:  Cars163.xml
# /kaggle/input/car-plate-detection/annotations/Cars163.xml
# box:(c,xmin,ymin,xmax,ymax) licence 220 173 360 200
# Dataset/train/labels/Cars163.txt
# file name:  Cars430.xml
# /kaggle/input/car-plate-detection/annotations/Cars430.xml
# box:(c,xmin,ymin,xmax,ymax) licence 38 159 116 197
# Dataset/train/labels/Cars430.txt
# file name:  Cars367.xml
# /kaggle/input/car-plate-detection/annotations/Cars367.xml
# box:(c,xmin,ymin,xmax,ymax) licence 224 161 382 222
# Dataset/train/labels/Cars367.txt
# file name:  Cars328.xml
# /kaggle/input/car-plate-detection/annotations/Cars328.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 149 248 170
# Dataset/train/labels/Cars328.txt
# file name:  Cars156.xml
# /kaggle/input/car-plate-detection/annotations/Cars156.xml
# box:(c,xmin,ymin,xmax,ymax) licence 114 78 230 102
# Dataset/train/labels/Cars156.txt
# file name:  Cars242.xml
# /kaggle/input/car-plate-detection/annotations/Cars242.xml
# box:(c,xmin,ymin,xmax,ymax) licence 224 170 277 199
# Dataset/train/labels/Cars242.txt
# file name:  Cars275.xml
# /kaggle/input/car-plate-detection/annotations/Cars275.xml
# box:(c,xmin,ymin,xmax,ymax) licence 99 150 162 167
# Dataset/train/labels/Cars275.txt
# file name:  Cars129.xml
# /kaggle/input/car-plate-detection/annotations/Cars129.xml
# box:(c,xmin,ymin,xmax,ymax) licence 204 213 282 267
# Dataset/train/labels/Cars129.txt
# file name:  Cars317.xml
# /kaggle/input/car-plate-detection/annotations/Cars317.xml
# box:(c,xmin,ymin,xmax,ymax) licence 164 202 240 220
# Dataset/train/labels/Cars317.txt
# file name:  Cars254.xml
# /kaggle/input/car-plate-detection/annotations/Cars254.xml
# box:(c,xmin,ymin,xmax,ymax) licence 166 175 235 207
# Dataset/train/labels/Cars254.txt
# file name:  Cars89.xml
# /kaggle/input/car-plate-detection/annotations/Cars89.xml
# box:(c,xmin,ymin,xmax,ymax) licence 307 206 345 221
# box:(c,xmin,ymin,xmax,ymax) licence 227 222 253 230
# Dataset/train/labels/Cars89.txt
# file name:  Cars187.xml
# /kaggle/input/car-plate-detection/annotations/Cars187.xml
# box:(c,xmin,ymin,xmax,ymax) licence 96 116 287 155
# Dataset/train/labels/Cars187.txt
# file name:  Cars388.xml
# /kaggle/input/car-plate-detection/annotations/Cars388.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 130 255 158
# Dataset/train/labels/Cars388.txt
# file name:  Cars376.xml
# /kaggle/input/car-plate-detection/annotations/Cars376.xml
# box:(c,xmin,ymin,xmax,ymax) licence 159 178 252 203
# Dataset/train/labels/Cars376.txt
# file name:  Cars67.xml
# /kaggle/input/car-plate-detection/annotations/Cars67.xml
# box:(c,xmin,ymin,xmax,ymax) licence 189 223 328 248
# Dataset/train/labels/Cars67.txt
# file name:  Cars408.xml
# /kaggle/input/car-plate-detection/annotations/Cars408.xml
# box:(c,xmin,ymin,xmax,ymax) licence 160 217 187 228
# Dataset/train/labels/Cars408.txt
# file name:  Cars405.xml
# /kaggle/input/car-plate-detection/annotations/Cars405.xml
# box:(c,xmin,ymin,xmax,ymax) licence 241 207 299 232
# Dataset/train/labels/Cars405.txt
# file name:  Cars292.xml
# /kaggle/input/car-plate-detection/annotations/Cars292.xml
# box:(c,xmin,ymin,xmax,ymax) licence 91 187 137 208
# Dataset/train/labels/Cars292.txt
# file name:  Cars327.xml
# /kaggle/input/car-plate-detection/annotations/Cars327.xml
# box:(c,xmin,ymin,xmax,ymax) licence 138 126 262 155
# Dataset/train/labels/Cars327.txt
# file name:  Cars344.xml
# /kaggle/input/car-plate-detection/annotations/Cars344.xml
# box:(c,xmin,ymin,xmax,ymax) licence 240 158 379 217
# Dataset/train/labels/Cars344.txt
# file name:  Cars325.xml
# /kaggle/input/car-plate-detection/annotations/Cars325.xml
# box:(c,xmin,ymin,xmax,ymax) licence 230 180 262 196
# Dataset/train/labels/Cars325.txt
# file name:  Cars257.xml
# /kaggle/input/car-plate-detection/annotations/Cars257.xml
# box:(c,xmin,ymin,xmax,ymax) licence 167 132 241 166
# Dataset/train/labels/Cars257.txt
# file name:  Cars319.xml
# /kaggle/input/car-plate-detection/annotations/Cars319.xml
# box:(c,xmin,ymin,xmax,ymax) licence 167 228 232 259
# Dataset/train/labels/Cars319.txt
# file name:  Cars120.xml
# /kaggle/input/car-plate-detection/annotations/Cars120.xml
# box:(c,xmin,ymin,xmax,ymax) licence 159 178 250 200
# Dataset/train/labels/Cars120.txt
# file name:  Cars31.xml
# /kaggle/input/car-plate-detection/annotations/Cars31.xml
# box:(c,xmin,ymin,xmax,ymax) licence 286 173 400 211
# Dataset/train/labels/Cars31.txt
# file name:  Cars428.xml
# /kaggle/input/car-plate-detection/annotations/Cars428.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 128 258 157
# Dataset/train/labels/Cars428.txt
# file name:  Cars164.xml
# /kaggle/input/car-plate-detection/annotations/Cars164.xml
# box:(c,xmin,ymin,xmax,ymax) licence 160 144 239 183
# Dataset/train/labels/Cars164.txt
# file name:  Cars290.xml
# /kaggle/input/car-plate-detection/annotations/Cars290.xml
# box:(c,xmin,ymin,xmax,ymax) licence 224 84 271 118
# Dataset/train/labels/Cars290.txt
# file name:  Cars426.xml
# /kaggle/input/car-plate-detection/annotations/Cars426.xml
# box:(c,xmin,ymin,xmax,ymax) licence 148 206 282 238
# Dataset/train/labels/Cars426.txt
# file name:  Cars37.xml
# /kaggle/input/car-plate-detection/annotations/Cars37.xml
# box:(c,xmin,ymin,xmax,ymax) licence 146 114 246 163
# Dataset/train/labels/Cars37.txt
# file name:  Cars216.xml
# /kaggle/input/car-plate-detection/annotations/Cars216.xml
# box:(c,xmin,ymin,xmax,ymax) licence 205 214 280 262
# Dataset/train/labels/Cars216.txt
# file name:  Cars75.xml
# /kaggle/input/car-plate-detection/annotations/Cars75.xml
# box:(c,xmin,ymin,xmax,ymax) licence 209 196 218 201
# Dataset/train/labels/Cars75.txt
# file name:  Cars160.xml
# /kaggle/input/car-plate-detection/annotations/Cars160.xml
# box:(c,xmin,ymin,xmax,ymax) licence 209 137 281 174
# Dataset/train/labels/Cars160.txt
# file name:  Cars209.xml
# /kaggle/input/car-plate-detection/annotations/Cars209.xml
# box:(c,xmin,ymin,xmax,ymax) licence 359 172 387 186
# Dataset/train/labels/Cars209.txt
# file name:  Cars190.xml
# /kaggle/input/car-plate-detection/annotations/Cars190.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 210 245 235
# Dataset/train/labels/Cars190.txt
# file name:  Cars322.xml
# /kaggle/input/car-plate-detection/annotations/Cars322.xml
# box:(c,xmin,ymin,xmax,ymax) licence 274 257 350 297
# Dataset/train/labels/Cars322.txt
# file name:  Cars5.xml
# /kaggle/input/car-plate-detection/annotations/Cars5.xml
# box:(c,xmin,ymin,xmax,ymax) licence 226 218 242 240
# Dataset/train/labels/Cars5.txt
# file name:  Cars63.xml
# /kaggle/input/car-plate-detection/annotations/Cars63.xml
# box:(c,xmin,ymin,xmax,ymax) licence 54 201 91 226
# Dataset/train/labels/Cars63.txt
# file name:  Cars104.xml
# /kaggle/input/car-plate-detection/annotations/Cars104.xml
# box:(c,xmin,ymin,xmax,ymax) licence 195 266 244 282
# Dataset/train/labels/Cars104.txt
# file name:  Cars424.xml
# /kaggle/input/car-plate-detection/annotations/Cars424.xml
# box:(c,xmin,ymin,xmax,ymax) licence 128 173 461 242
# Dataset/train/labels/Cars424.txt
# file name:  Cars316.xml
# /kaggle/input/car-plate-detection/annotations/Cars316.xml
# box:(c,xmin,ymin,xmax,ymax) licence 377 405 476 439
# box:(c,xmin,ymin,xmax,ymax) licence 379 192 455 220
# Dataset/train/labels/Cars316.txt
# file name:  Cars387.xml
# /kaggle/input/car-plate-detection/annotations/Cars387.xml
# box:(c,xmin,ymin,xmax,ymax) licence 163 187 256 225
# Dataset/train/labels/Cars387.txt
# file name:  Cars56.xml
# /kaggle/input/car-plate-detection/annotations/Cars56.xml
# box:(c,xmin,ymin,xmax,ymax) licence 87 82 339 146
# Dataset/train/labels/Cars56.txt
# file name:  Cars10.xml
# /kaggle/input/car-plate-detection/annotations/Cars10.xml
# box:(c,xmin,ymin,xmax,ymax) licence 140 5 303 148
# Dataset/train/labels/Cars10.txt
# file name:  Cars374.xml
# /kaggle/input/car-plate-detection/annotations/Cars374.xml
# box:(c,xmin,ymin,xmax,ymax) licence 354 118 441 142
# Dataset/train/labels/Cars374.txt
# file name:  Cars274.xml
# /kaggle/input/car-plate-detection/annotations/Cars274.xml
# box:(c,xmin,ymin,xmax,ymax) licence 196 149 253 169
# Dataset/train/labels/Cars274.txt
# file name:  Cars300.xml
# /kaggle/input/car-plate-detection/annotations/Cars300.xml
# box:(c,xmin,ymin,xmax,ymax) licence 259 185 317 215
# Dataset/train/labels/Cars300.txt
# file name:  Cars432.xml
# /kaggle/input/car-plate-detection/annotations/Cars432.xml
# box:(c,xmin,ymin,xmax,ymax) licence 95 258 196 284
# Dataset/train/labels/Cars432.txt
# file name:  Cars273.xml
# /kaggle/input/car-plate-detection/annotations/Cars273.xml
# box:(c,xmin,ymin,xmax,ymax) licence 74 132 264 173
# Dataset/train/labels/Cars273.txt
# file name:  Cars185.xml
# /kaggle/input/car-plate-detection/annotations/Cars185.xml
# box:(c,xmin,ymin,xmax,ymax) licence 154 147 293 194
# Dataset/train/labels/Cars185.txt
# file name:  Cars418.xml
# /kaggle/input/car-plate-detection/annotations/Cars418.xml
# box:(c,xmin,ymin,xmax,ymax) licence 99 70 303 155
# Dataset/train/labels/Cars418.txt
# file name:  Cars204.xml
# /kaggle/input/car-plate-detection/annotations/Cars204.xml
# box:(c,xmin,ymin,xmax,ymax) licence 193 145 279 187
# Dataset/train/labels/Cars204.txt
# file name:  Cars88.xml
# /kaggle/input/car-plate-detection/annotations/Cars88.xml
# box:(c,xmin,ymin,xmax,ymax) licence 168 148 242 171
# Dataset/train/labels/Cars88.txt
# file name:  Cars195.xml
# /kaggle/input/car-plate-detection/annotations/Cars195.xml
# box:(c,xmin,ymin,xmax,ymax) licence 450 223 526 244
# Dataset/train/labels/Cars195.txt
# file name:  Cars106.xml
# /kaggle/input/car-plate-detection/annotations/Cars106.xml
# box:(c,xmin,ymin,xmax,ymax) licence 138 79 177 92
# box:(c,xmin,ymin,xmax,ymax) licence 245 79 270 94
# box:(c,xmin,ymin,xmax,ymax) licence 169 202 192 231
# box:(c,xmin,ymin,xmax,ymax) licence 225 194 279 217
# Dataset/train/labels/Cars106.txt
# file name:  Cars152.xml
# /kaggle/input/car-plate-detection/annotations/Cars152.xml
# box:(c,xmin,ymin,xmax,ymax) licence 92 258 199 284
# Dataset/train/labels/Cars152.txt
# file name:  Cars296.xml
# /kaggle/input/car-plate-detection/annotations/Cars296.xml
# box:(c,xmin,ymin,xmax,ymax) licence 163 158 234 196
# Dataset/train/labels/Cars296.txt
# file name:  Cars65.xml
# /kaggle/input/car-plate-detection/annotations/Cars65.xml
# box:(c,xmin,ymin,xmax,ymax) licence 207 200 300 260
# Dataset/train/labels/Cars65.txt
# file name:  Cars208.xml
# /kaggle/input/car-plate-detection/annotations/Cars208.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 123 232 169
# Dataset/train/labels/Cars208.txt
# file name:  Cars86.xml
# /kaggle/input/car-plate-detection/annotations/Cars86.xml
# box:(c,xmin,ymin,xmax,ymax) licence 332 176 447 204
# Dataset/train/labels/Cars86.txt
# file name:  Cars324.xml
# /kaggle/input/car-plate-detection/annotations/Cars324.xml
# box:(c,xmin,ymin,xmax,ymax) licence 151 138 255 159
# Dataset/train/labels/Cars324.txt
# file name:  Cars282.xml
# /kaggle/input/car-plate-detection/annotations/Cars282.xml
# box:(c,xmin,ymin,xmax,ymax) licence 37 145 319 203
# Dataset/train/labels/Cars282.txt
# file name:  Cars263.xml
# /kaggle/input/car-plate-detection/annotations/Cars263.xml
# box:(c,xmin,ymin,xmax,ymax) licence 129 260 232 290
# Dataset/train/labels/Cars263.txt
# file name:  Cars6.xml
# /kaggle/input/car-plate-detection/annotations/Cars6.xml
# box:(c,xmin,ymin,xmax,ymax) licence 112 114 373 239
# Dataset/train/labels/Cars6.txt
# file name:  Cars27.xml
# /kaggle/input/car-plate-detection/annotations/Cars27.xml
# box:(c,xmin,ymin,xmax,ymax) licence 148 127 245 159
# Dataset/train/labels/Cars27.txt
# file name:  Cars32.xml
# /kaggle/input/car-plate-detection/annotations/Cars32.xml
# box:(c,xmin,ymin,xmax,ymax) licence 200 149 251 167
# Dataset/train/labels/Cars32.txt
# file name:  Cars181.xml
# /kaggle/input/car-plate-detection/annotations/Cars181.xml
# box:(c,xmin,ymin,xmax,ymax) licence 69 195 128 209
# Dataset/train/labels/Cars181.txt
# file name:  Cars333.xml
# /kaggle/input/car-plate-detection/annotations/Cars333.xml
# box:(c,xmin,ymin,xmax,ymax) licence 117 157 270 191
# Dataset/train/labels/Cars333.txt
# file name:  Cars311.xml
# /kaggle/input/car-plate-detection/annotations/Cars311.xml
# box:(c,xmin,ymin,xmax,ymax) licence 295 166 355 185
# box:(c,xmin,ymin,xmax,ymax) licence 67 91 95 98
# Dataset/train/labels/Cars311.txt
# file name:  Cars357.xml
# /kaggle/input/car-plate-detection/annotations/Cars357.xml
# box:(c,xmin,ymin,xmax,ymax) licence 92 187 137 207
# Dataset/train/labels/Cars357.txt
# file name:  Cars265.xml
# /kaggle/input/car-plate-detection/annotations/Cars265.xml
# box:(c,xmin,ymin,xmax,ymax) licence 87 166 216 212
# Dataset/train/labels/Cars265.txt
# file name:  Cars396.xml
# /kaggle/input/car-plate-detection/annotations/Cars396.xml
# box:(c,xmin,ymin,xmax,ymax) licence 181 264 269 289
# Dataset/train/labels/Cars396.txt
# file name:  Cars403.xml
# /kaggle/input/car-plate-detection/annotations/Cars403.xml
# box:(c,xmin,ymin,xmax,ymax) licence 296 189 332 209
# box:(c,xmin,ymin,xmax,ymax) licence 23 173 54 192
# Dataset/train/labels/Cars403.txt
# file name:  Cars284.xml
# /kaggle/input/car-plate-detection/annotations/Cars284.xml
# box:(c,xmin,ymin,xmax,ymax) licence 70 199 260 271
# Dataset/train/labels/Cars284.txt
# file name:  Cars118.xml
# /kaggle/input/car-plate-detection/annotations/Cars118.xml
# box:(c,xmin,ymin,xmax,ymax) licence 193 165 394 217
# Dataset/train/labels/Cars118.txt
# file name:  Cars372.xml
# /kaggle/input/car-plate-detection/annotations/Cars372.xml
# box:(c,xmin,ymin,xmax,ymax) licence 221 275 353 309
# Dataset/train/labels/Cars372.txt
# file name:  Cars71.xml
# /kaggle/input/car-plate-detection/annotations/Cars71.xml
# box:(c,xmin,ymin,xmax,ymax) licence 254 144 284 152
# box:(c,xmin,ymin,xmax,ymax) licence 86 150 125 161
# Dataset/train/labels/Cars71.txt
# file name:  Cars142.xml
# /kaggle/input/car-plate-detection/annotations/Cars142.xml
# box:(c,xmin,ymin,xmax,ymax) licence 178 124 273 144
# Dataset/train/labels/Cars142.txt
# file name:  Cars416.xml
# /kaggle/input/car-plate-detection/annotations/Cars416.xml
# box:(c,xmin,ymin,xmax,ymax) licence 150 207 234 221
# Dataset/train/labels/Cars416.txt
# file name:  Cars21.xml
# /kaggle/input/car-plate-detection/annotations/Cars21.xml
# box:(c,xmin,ymin,xmax,ymax) licence 191 165 255 192
# Dataset/train/labels/Cars21.txt
# file name:  Cars93.xml
# /kaggle/input/car-plate-detection/annotations/Cars93.xml
# box:(c,xmin,ymin,xmax,ymax) licence 347 122 367 132
# Dataset/train/labels/Cars93.txt
# file name:  Cars113.xml
# /kaggle/input/car-plate-detection/annotations/Cars113.xml
# box:(c,xmin,ymin,xmax,ymax) licence 151 113 306 180
# Dataset/train/labels/Cars113.txt
# file name:  Cars109.xml
# /kaggle/input/car-plate-detection/annotations/Cars109.xml
# box:(c,xmin,ymin,xmax,ymax) licence 115 116 278 153
# Dataset/train/labels/Cars109.txt
# file name:  Cars264.xml
# /kaggle/input/car-plate-detection/annotations/Cars264.xml
# box:(c,xmin,ymin,xmax,ymax) licence 222 300 295 337
# Dataset/train/labels/Cars264.txt
# file name:  Cars250.xml
# /kaggle/input/car-plate-detection/annotations/Cars250.xml
# box:(c,xmin,ymin,xmax,ymax) licence 132 123 261 160
# Dataset/train/labels/Cars250.txt
# file name:  Cars298.xml
# /kaggle/input/car-plate-detection/annotations/Cars298.xml
# box:(c,xmin,ymin,xmax,ymax) licence 166 148 233 184
# Dataset/train/labels/Cars298.txt
# file name:  Cars36.xml
# /kaggle/input/car-plate-detection/annotations/Cars36.xml
# box:(c,xmin,ymin,xmax,ymax) licence 203 193 285 229
# Dataset/train/labels/Cars36.txt
# file name:  Cars158.xml
# /kaggle/input/car-plate-detection/annotations/Cars158.xml
# box:(c,xmin,ymin,xmax,ymax) licence 97 118 296 210
# Dataset/train/labels/Cars158.txt
# file name:  Cars230.xml
# /kaggle/input/car-plate-detection/annotations/Cars230.xml
# box:(c,xmin,ymin,xmax,ymax) licence 222 173 361 202
# Dataset/train/labels/Cars230.txt
# file name:  Cars346.xml
# /kaggle/input/car-plate-detection/annotations/Cars346.xml
# box:(c,xmin,ymin,xmax,ymax) licence 91 185 197 217
# Dataset/train/labels/Cars346.txt
# file name:  Cars64.xml
# /kaggle/input/car-plate-detection/annotations/Cars64.xml
# box:(c,xmin,ymin,xmax,ymax) licence 120 187 325 220
# Dataset/train/labels/Cars64.txt
# file name:  Cars98.xml
# /kaggle/input/car-plate-detection/annotations/Cars98.xml
# box:(c,xmin,ymin,xmax,ymax) licence 85 196 247 259
# Dataset/train/labels/Cars98.txt
# file name:  Cars380.xml
# /kaggle/input/car-plate-detection/annotations/Cars380.xml
# box:(c,xmin,ymin,xmax,ymax) licence 316 91 364 126
# Dataset/train/labels/Cars380.txt
# file name:  Cars221.xml
# /kaggle/input/car-plate-detection/annotations/Cars221.xml
# box:(c,xmin,ymin,xmax,ymax) licence 102 122 125 135
# Dataset/train/labels/Cars221.txt
# file name:  Cars277.xml
# /kaggle/input/car-plate-detection/annotations/Cars277.xml
# box:(c,xmin,ymin,xmax,ymax) licence 48 218 72 225
# box:(c,xmin,ymin,xmax,ymax) licence 134 217 153 224
# box:(c,xmin,ymin,xmax,ymax) licence 290 220 308 229
# box:(c,xmin,ymin,xmax,ymax) licence 373 212 388 217
# Dataset/train/labels/Cars277.txt
# file name:  Cars19.xml
# /kaggle/input/car-plate-detection/annotations/Cars19.xml
# box:(c,xmin,ymin,xmax,ymax) licence 148 195 221 232
# Dataset/train/labels/Cars19.txt
# file name:  Cars217.xml
# /kaggle/input/car-plate-detection/annotations/Cars217.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 196 223 231
# Dataset/train/labels/Cars217.txt
# file name:  Cars415.xml
# /kaggle/input/car-plate-detection/annotations/Cars415.xml
# box:(c,xmin,ymin,xmax,ymax) licence 133 157 261 192
# Dataset/train/labels/Cars415.txt
# file name:  Cars157.xml
# /kaggle/input/car-plate-detection/annotations/Cars157.xml
# box:(c,xmin,ymin,xmax,ymax) licence 330 152 366 179
# Dataset/train/labels/Cars157.txt
# file name:  Cars57.xml
# /kaggle/input/car-plate-detection/annotations/Cars57.xml
# box:(c,xmin,ymin,xmax,ymax) licence 270 162 321 195
# Dataset/train/labels/Cars57.txt
# file name:  Cars97.xml
# /kaggle/input/car-plate-detection/annotations/Cars97.xml
# box:(c,xmin,ymin,xmax,ymax) licence 98 102 297 191
# Dataset/train/labels/Cars97.txt
# file name:  Cars310.xml
# /kaggle/input/car-plate-detection/annotations/Cars310.xml
# box:(c,xmin,ymin,xmax,ymax) licence 241 369 348 417
# Dataset/train/labels/Cars310.txt
# file name:  Cars78.xml
# /kaggle/input/car-plate-detection/annotations/Cars78.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 210 249 239
# Dataset/train/labels/Cars78.txt
# file name:  Cars260.xml
# /kaggle/input/car-plate-detection/annotations/Cars260.xml
# box:(c,xmin,ymin,xmax,ymax) licence 170 112 232 129
# Dataset/train/labels/Cars260.txt
# file name:  Cars15.xml
# /kaggle/input/car-plate-detection/annotations/Cars15.xml
# box:(c,xmin,ymin,xmax,ymax) licence 310 146 372 171
# Dataset/train/labels/Cars15.txt
# file name:  Cars271.xml
# /kaggle/input/car-plate-detection/annotations/Cars271.xml
# box:(c,xmin,ymin,xmax,ymax) licence 262 141 318 160
# Dataset/train/labels/Cars271.txt
# file name:  Cars326.xml
# /kaggle/input/car-plate-detection/annotations/Cars326.xml
# box:(c,xmin,ymin,xmax,ymax) licence 141 198 252 230
# Dataset/train/labels/Cars326.txt
# file name:  Cars394.xml
# /kaggle/input/car-plate-detection/annotations/Cars394.xml
# box:(c,xmin,ymin,xmax,ymax) licence 291 167 410 190
# Dataset/train/labels/Cars394.txt
# file name:  Cars167.xml
# /kaggle/input/car-plate-detection/annotations/Cars167.xml
# box:(c,xmin,ymin,xmax,ymax) licence 176 254 327 285
# Dataset/train/labels/Cars167.txt
# file name:  Cars270.xml
# /kaggle/input/car-plate-detection/annotations/Cars270.xml
# box:(c,xmin,ymin,xmax,ymax) licence 75 173 125 195
# Dataset/train/labels/Cars270.txt
# file name:  Cars219.xml
# /kaggle/input/car-plate-detection/annotations/Cars219.xml
# box:(c,xmin,ymin,xmax,ymax) licence 127 172 462 236
# Dataset/train/labels/Cars219.txt
# file name:  Cars148.xml
# /kaggle/input/car-plate-detection/annotations/Cars148.xml
# box:(c,xmin,ymin,xmax,ymax) licence 135 134 218 158
# Dataset/train/labels/Cars148.txt
# file name:  Cars90.xml
# /kaggle/input/car-plate-detection/annotations/Cars90.xml
# box:(c,xmin,ymin,xmax,ymax) licence 77 204 101 225
# Dataset/train/labels/Cars90.txt
# file name:  Cars281.xml
# /kaggle/input/car-plate-detection/annotations/Cars281.xml
# box:(c,xmin,ymin,xmax,ymax) licence 151 169 243 183
# Dataset/train/labels/Cars281.txt
# file name:  Cars44.xml
# /kaggle/input/car-plate-detection/annotations/Cars44.xml
# box:(c,xmin,ymin,xmax,ymax) licence 18 153 430 271
# Dataset/train/labels/Cars44.txt
# file name:  Cars94.xml
# /kaggle/input/car-plate-detection/annotations/Cars94.xml
# box:(c,xmin,ymin,xmax,ymax) licence 176 210 251 248
# Dataset/train/labels/Cars94.txt
# file name:  Cars266.xml
# /kaggle/input/car-plate-detection/annotations/Cars266.xml
# box:(c,xmin,ymin,xmax,ymax) licence 11 57 88 76
# box:(c,xmin,ymin,xmax,ymax) licence 15 84 84 102
# box:(c,xmin,ymin,xmax,ymax) licence 23 110 75 122
# box:(c,xmin,ymin,xmax,ymax) licence 24 150 74 175
# box:(c,xmin,ymin,xmax,ymax) licence 95 105 158 122
# box:(c,xmin,ymin,xmax,ymax) licence 154 45 393 176
# Dataset/train/labels/Cars266.txt
# file name:  Cars393.xml
# /kaggle/input/car-plate-detection/annotations/Cars393.xml
# box:(c,xmin,ymin,xmax,ymax) licence 94 171 211 208
# Dataset/train/labels/Cars393.txt
# file name:  Cars48.xml
# /kaggle/input/car-plate-detection/annotations/Cars48.xml
# box:(c,xmin,ymin,xmax,ymax) licence 95 117 286 155
# Dataset/train/labels/Cars48.txt
# file name:  Cars218.xml
# /kaggle/input/car-plate-detection/annotations/Cars218.xml
# box:(c,xmin,ymin,xmax,ymax) licence 0 166 27 188
# Dataset/train/labels/Cars218.txt
# file name:  Cars306.xml
# /kaggle/input/car-plate-detection/annotations/Cars306.xml
# box:(c,xmin,ymin,xmax,ymax) licence 139 282 249 310
# Dataset/train/labels/Cars306.txt
# file name:  Cars91.xml
# /kaggle/input/car-plate-detection/annotations/Cars91.xml
# box:(c,xmin,ymin,xmax,ymax) licence 269 170 317 189
# Dataset/train/labels/Cars91.txt
# file name:  Cars368.xml
# /kaggle/input/car-plate-detection/annotations/Cars368.xml
# box:(c,xmin,ymin,xmax,ymax) licence 173 173 223 203
# Dataset/train/labels/Cars368.txt
# file name:  Cars159.xml
# /kaggle/input/car-plate-detection/annotations/Cars159.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 184 261 211
# Dataset/train/labels/Cars159.txt
# file name:  Cars133.xml
# /kaggle/input/car-plate-detection/annotations/Cars133.xml
# box:(c,xmin,ymin,xmax,ymax) licence 247 185 375 223
# Dataset/train/labels/Cars133.txt
# file name:  Cars288.xml
# /kaggle/input/car-plate-detection/annotations/Cars288.xml
# box:(c,xmin,ymin,xmax,ymax) licence 97 148 164 169
# Dataset/train/labels/Cars288.txt
# file name:  Cars336.xml
# /kaggle/input/car-plate-detection/annotations/Cars336.xml
# box:(c,xmin,ymin,xmax,ymax) licence 122 195 265 234
# Dataset/train/labels/Cars336.txt
# file name:  Cars140.xml
# /kaggle/input/car-plate-detection/annotations/Cars140.xml
# box:(c,xmin,ymin,xmax,ymax) licence 283 239 424 286
# Dataset/train/labels/Cars140.txt
# file name:  Cars18.xml
# /kaggle/input/car-plate-detection/annotations/Cars18.xml
# box:(c,xmin,ymin,xmax,ymax) licence 313 286 405 311
# Dataset/train/labels/Cars18.txt
# file name:  Cars179.xml
# /kaggle/input/car-plate-detection/annotations/Cars179.xml
# box:(c,xmin,ymin,xmax,ymax) licence 72 160 132 197
# Dataset/train/labels/Cars179.txt
# file name:  Cars206.xml
# /kaggle/input/car-plate-detection/annotations/Cars206.xml
# box:(c,xmin,ymin,xmax,ymax) licence 95 185 164 206
# Dataset/train/labels/Cars206.txt
# file name:  Cars92.xml
# /kaggle/input/car-plate-detection/annotations/Cars92.xml
# box:(c,xmin,ymin,xmax,ymax) licence 281 185 393 271
# Dataset/train/labels/Cars92.txt
# file name:  Cars390.xml
# /kaggle/input/car-plate-detection/annotations/Cars390.xml
# box:(c,xmin,ymin,xmax,ymax) licence 360 118 397 136
# box:(c,xmin,ymin,xmax,ymax) licence 6 144 49 162
# Dataset/train/labels/Cars390.txt
# file name:  Cars351.xml
# /kaggle/input/car-plate-detection/annotations/Cars351.xml
# box:(c,xmin,ymin,xmax,ymax) licence 249 48 368 129
# Dataset/train/labels/Cars351.txt
# file name:  Cars352.xml
# /kaggle/input/car-plate-detection/annotations/Cars352.xml
# box:(c,xmin,ymin,xmax,ymax) licence 201 185 217 195
# box:(c,xmin,ymin,xmax,ymax) licence 77 181 94 191
# Dataset/train/labels/Cars352.txt
# file name:  Cars49.xml
# /kaggle/input/car-plate-detection/annotations/Cars49.xml
# box:(c,xmin,ymin,xmax,ymax) licence 268 171 314 190
# Dataset/train/labels/Cars49.txt
# file name:  Cars294.xml
# /kaggle/input/car-plate-detection/annotations/Cars294.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 117 218 135
# Dataset/train/labels/Cars294.txt
# file name:  Cars35.xml
# /kaggle/input/car-plate-detection/annotations/Cars35.xml
# box:(c,xmin,ymin,xmax,ymax) licence 91 186 137 208
# Dataset/train/labels/Cars35.txt
# file name:  Cars315.xml
# /kaggle/input/car-plate-detection/annotations/Cars315.xml
# box:(c,xmin,ymin,xmax,ymax) licence 12 98 385 181
# Dataset/train/labels/Cars315.txt
# file name:  Cars138.xml
# /kaggle/input/car-plate-detection/annotations/Cars138.xml
# box:(c,xmin,ymin,xmax,ymax) licence 153 141 254 185
# Dataset/train/labels/Cars138.txt
# file name:  Cars391.xml
# /kaggle/input/car-plate-detection/annotations/Cars391.xml
# box:(c,xmin,ymin,xmax,ymax) licence 270 163 320 190
# Dataset/train/labels/Cars391.txt
# file name:  Cars245.xml
# /kaggle/input/car-plate-detection/annotations/Cars245.xml
# box:(c,xmin,ymin,xmax,ymax) licence 91 110 164 138
# Dataset/train/labels/Cars245.txt
# file name:  Cars205.xml
# /kaggle/input/car-plate-detection/annotations/Cars205.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 162 221 199
# Dataset/train/labels/Cars205.txt
# file name:  Cars210.xml
# /kaggle/input/car-plate-detection/annotations/Cars210.xml
# box:(c,xmin,ymin,xmax,ymax) licence 54 90 315 159
# Dataset/train/labels/Cars210.txt
# file name:  Cars169.xml
# /kaggle/input/car-plate-detection/annotations/Cars169.xml
# box:(c,xmin,ymin,xmax,ymax) licence 114 79 229 101
# Dataset/train/labels/Cars169.txt
# file name:  Cars402.xml
# /kaggle/input/car-plate-detection/annotations/Cars402.xml
# box:(c,xmin,ymin,xmax,ymax) licence 360 165 438 181
# Dataset/train/labels/Cars402.txt
# file name:  Cars170.xml
# /kaggle/input/car-plate-detection/annotations/Cars170.xml
# box:(c,xmin,ymin,xmax,ymax) licence 318 190 346 224
# Dataset/train/labels/Cars170.txt
# file name:  Cars180.xml
# /kaggle/input/car-plate-detection/annotations/Cars180.xml
# box:(c,xmin,ymin,xmax,ymax) licence 151 115 304 187
# Dataset/train/labels/Cars180.txt
# file name:  Cars193.xml
# /kaggle/input/car-plate-detection/annotations/Cars193.xml
# box:(c,xmin,ymin,xmax,ymax) licence 306 193 344 214
# Dataset/train/labels/Cars193.txt
# file name:  Cars144.xml
# /kaggle/input/car-plate-detection/annotations/Cars144.xml
# box:(c,xmin,ymin,xmax,ymax) licence 101 114 215 154
# Dataset/train/labels/Cars144.txt
# file name:  Cars287.xml
# /kaggle/input/car-plate-detection/annotations/Cars287.xml
# box:(c,xmin,ymin,xmax,ymax) licence 148 180 262 213
# Dataset/train/labels/Cars287.txt
# file name:  Cars276.xml
# /kaggle/input/car-plate-detection/annotations/Cars276.xml
# box:(c,xmin,ymin,xmax,ymax) licence 115 116 276 156
# Dataset/train/labels/Cars276.txt
# file name:  Cars247.xml
# /kaggle/input/car-plate-detection/annotations/Cars247.xml
# box:(c,xmin,ymin,xmax,ymax) licence 147 11 300 149
# Dataset/train/labels/Cars247.txt
# file name:  Cars29.xml
# /kaggle/input/car-plate-detection/annotations/Cars29.xml
# box:(c,xmin,ymin,xmax,ymax) licence 143 171 211 208
# Dataset/train/labels/Cars29.txt
# file name:  Cars105.xml
# /kaggle/input/car-plate-detection/annotations/Cars105.xml
# box:(c,xmin,ymin,xmax,ymax) licence 152 147 206 159
# Dataset/train/labels/Cars105.txt
# file name:  Cars62.xml
# /kaggle/input/car-plate-detection/annotations/Cars62.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 110 243 159
# Dataset/train/labels/Cars62.txt
# file name:  Cars229.xml
# /kaggle/input/car-plate-detection/annotations/Cars229.xml
# box:(c,xmin,ymin,xmax,ymax) licence 253 163 284 177
# Dataset/train/labels/Cars229.txt
# file name:  Cars377.xml
# /kaggle/input/car-plate-detection/annotations/Cars377.xml
# box:(c,xmin,ymin,xmax,ymax) licence 177 138 216 161
# Dataset/train/labels/Cars377.txt
# file name:  Cars278.xml
# /kaggle/input/car-plate-detection/annotations/Cars278.xml
# box:(c,xmin,ymin,xmax,ymax) licence 278 138 315 163
# Dataset/train/labels/Cars278.txt
# file name:  Cars253.xml
# /kaggle/input/car-plate-detection/annotations/Cars253.xml
# box:(c,xmin,ymin,xmax,ymax) licence 25 124 64 137
# Dataset/train/labels/Cars253.txt
# file name:  Cars198.xml
# /kaggle/input/car-plate-detection/annotations/Cars198.xml
# box:(c,xmin,ymin,xmax,ymax) licence 166 225 273 246
# Dataset/train/labels/Cars198.txt
# file name:  Cars355.xml
# /kaggle/input/car-plate-detection/annotations/Cars355.xml
# box:(c,xmin,ymin,xmax,ymax) licence 164 154 239 190
# Dataset/train/labels/Cars355.txt
# file name:  Cars46.xml
# /kaggle/input/car-plate-detection/annotations/Cars46.xml
# box:(c,xmin,ymin,xmax,ymax) licence 189 193 352 248
# Dataset/train/labels/Cars46.txt
# file name:  Cars70.xml
# /kaggle/input/car-plate-detection/annotations/Cars70.xml
# box:(c,xmin,ymin,xmax,ymax) licence 179 115 213 133
# Dataset/train/labels/Cars70.txt
# file name:  Cars348.xml
# /kaggle/input/car-plate-detection/annotations/Cars348.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 121 250 204
# Dataset/train/labels/Cars348.txt
# file name:  Cars386.xml
# /kaggle/input/car-plate-detection/annotations/Cars386.xml
# box:(c,xmin,ymin,xmax,ymax) licence 83 307 221 368
# Dataset/train/labels/Cars386.txt
# file name:  Cars139.xml
# /kaggle/input/car-plate-detection/annotations/Cars139.xml
# box:(c,xmin,ymin,xmax,ymax) licence 315 189 337 197
# box:(c,xmin,ymin,xmax,ymax) licence 193 224 231 233
# Dataset/train/labels/Cars139.txt
# file name:  Cars137.xml
# /kaggle/input/car-plate-detection/annotations/Cars137.xml
# box:(c,xmin,ymin,xmax,ymax) licence 178 181 204 191
# Dataset/train/labels/Cars137.txt
# file name:  Cars252.xml
# /kaggle/input/car-plate-detection/annotations/Cars252.xml
# box:(c,xmin,ymin,xmax,ymax) licence 174 237 314 274
# Dataset/train/labels/Cars252.txt
# file name:  Cars95.xml
# /kaggle/input/car-plate-detection/annotations/Cars95.xml
# box:(c,xmin,ymin,xmax,ymax) licence 278 182 407 263
# Dataset/train/labels/Cars95.txt
# file name:  Cars305.xml
# /kaggle/input/car-plate-detection/annotations/Cars305.xml
# box:(c,xmin,ymin,xmax,ymax) licence 361 167 434 183
# Dataset/train/labels/Cars305.txt
# file name:  Cars329.xml
# /kaggle/input/car-plate-detection/annotations/Cars329.xml
# box:(c,xmin,ymin,xmax,ymax) licence 166 142 224 176
# Dataset/train/labels/Cars329.txt
# file name:  Cars385.xml
# /kaggle/input/car-plate-detection/annotations/Cars385.xml
# box:(c,xmin,ymin,xmax,ymax) licence 69 75 310 191
# Dataset/train/labels/Cars385.txt
# file name:  Cars232.xml
# ...
# box:(c,xmin,ymin,xmax,ymax) licence 97 138 234 170
# Dataset/train/labels/Cars183.txt
# file name:  Cars173.xml
# /kaggle/input/car-plate-detection/annotations/Cars173.xml
# box:(c,xmin,ymin,xmax,ymax) licence 170 118 252 163
# Dataset/train/labels/Cars173.txt
# file name:  Cars194.xml
# /kaggle/input/car-plate-detection/annotations/Cars194.xml
# box:(c,xmin,ymin,xmax,ymax) licence 267 170 316 183
# Dataset/train/labels/Cars194.txt
# file name:  Cars286.xml
# /kaggle/input/car-plate-detection/annotations/Cars286.xml
# box:(c,xmin,ymin,xmax,ymax) licence 201 191 288 230
# Dataset/train/labels/Cars286.txt
# file name:  Cars50.xml
# /kaggle/input/car-plate-detection/annotations/Cars50.xml
# box:(c,xmin,ymin,xmax,ymax) licence 116 55 525 262
# Dataset/train/labels/Cars50.txt
# file name:  Cars101.xml
# /kaggle/input/car-plate-detection/annotations/Cars101.xml
# box:(c,xmin,ymin,xmax,ymax) licence 167 202 240 220
# Dataset/train/labels/Cars101.txt
# file name:  Cars125.xml
# /kaggle/input/car-plate-detection/annotations/Cars125.xml
# box:(c,xmin,ymin,xmax,ymax) licence 280 196 355 257
# Dataset/train/labels/Cars125.txt
# file name:  Cars334.xml
# /kaggle/input/car-plate-detection/annotations/Cars334.xml
# box:(c,xmin,ymin,xmax,ymax) licence 155 146 211 162
# Dataset/train/labels/Cars334.txt
# file name:  Cars149.xml
# /kaggle/input/car-plate-detection/annotations/Cars149.xml
# box:(c,xmin,ymin,xmax,ymax) licence 212 182 245 203
# Dataset/train/labels/Cars149.txt
# file name:  Cars332.xml
# /kaggle/input/car-plate-detection/annotations/Cars332.xml
# box:(c,xmin,ymin,xmax,ymax) licence 143 126 260 159
# Dataset/train/labels/Cars332.txt
# file name:  Cars320.xml
# /kaggle/input/car-plate-detection/annotations/Cars320.xml
# box:(c,xmin,ymin,xmax,ymax) licence 99 225 257 266
# Dataset/train/labels/Cars320.txt
# file name:  Cars293.xml
# /kaggle/input/car-plate-detection/annotations/Cars293.xml
# box:(c,xmin,ymin,xmax,ymax) licence 64 160 130 181
# Dataset/train/labels/Cars293.txt
# file name:  Cars234.xml
# /kaggle/input/car-plate-detection/annotations/Cars234.xml
# box:(c,xmin,ymin,xmax,ymax) licence 160 149 246 171
# Dataset/train/labels/Cars234.txt
# file name:  Cars178.xml
# /kaggle/input/car-plate-detection/annotations/Cars178.xml
# box:(c,xmin,ymin,xmax,ymax) licence 126 180 173 205
# Dataset/train/labels/Cars178.txt
# file name:  Cars410.xml
# /kaggle/input/car-plate-detection/annotations/Cars410.xml
# box:(c,xmin,ymin,xmax,ymax) licence 51 150 219 212
# Dataset/train/labels/Cars410.txt
# file name:  Cars330.xml
# /kaggle/input/car-plate-detection/annotations/Cars330.xml
# box:(c,xmin,ymin,xmax,ymax) licence 29 192 57 203
# box:(c,xmin,ymin,xmax,ymax) licence 168 202 198 214
# box:(c,xmin,ymin,xmax,ymax) licence 313 180 333 191
# box:(c,xmin,ymin,xmax,ymax) licence 385 172 399 181
# Dataset/train/labels/Cars330.txt
# file name:  Cars356.xml
# /kaggle/input/car-plate-detection/annotations/Cars356.xml
# box:(c,xmin,ymin,xmax,ymax) licence 241 216 364 275
# Dataset/train/labels/Cars356.txt
# file name:  Cars110.xml
# /kaggle/input/car-plate-detection/annotations/Cars110.xml
# box:(c,xmin,ymin,xmax,ymax) licence 286 133 328 159
# Dataset/train/labels/Cars110.txt
# file name:  Cars398.xml
# /kaggle/input/car-plate-detection/annotations/Cars398.xml
# box:(c,xmin,ymin,xmax,ymax) licence 72 139 196 222
# Dataset/train/labels/Cars398.txt
# file name:  Cars130.xml
# /kaggle/input/car-plate-detection/annotations/Cars130.xml
# box:(c,xmin,ymin,xmax,ymax) licence 91 110 166 140
# Dataset/train/labels/Cars130.txt
# file name:  Cars213.xml
# /kaggle/input/car-plate-detection/annotations/Cars213.xml
# box:(c,xmin,ymin,xmax,ymax) licence 150 160 233 194
# Dataset/train/labels/Cars213.txt
# file name:  Cars238.xml
# /kaggle/input/car-plate-detection/annotations/Cars238.xml
# box:(c,xmin,ymin,xmax,ymax) licence 276 186 396 273
# Dataset/train/labels/Cars238.txt
# file name:  Cars212.xml
# /kaggle/input/car-plate-detection/annotations/Cars212.xml
# box:(c,xmin,ymin,xmax,ymax) licence 105 94 290 141
# Dataset/train/labels/Cars212.txt
# file name:  Cars161.xml
# /kaggle/input/car-plate-detection/annotations/Cars161.xml
# box:(c,xmin,ymin,xmax,ymax) licence 312 283 406 311
# Dataset/train/labels/Cars161.txt
# file name:  Cars41.xml
# /kaggle/input/car-plate-detection/annotations/Cars41.xml
# box:(c,xmin,ymin,xmax,ymax) licence 109 182 159 206
# Dataset/train/labels/Cars41.txt
# file name:  Cars176.xml
# /kaggle/input/car-plate-detection/annotations/Cars176.xml
# box:(c,xmin,ymin,xmax,ymax) licence 72 67 308 185
# Dataset/train/labels/Cars176.txt
# file name:  Cars43.xml
# /kaggle/input/car-plate-detection/annotations/Cars43.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 111 319 161
# Dataset/train/labels/Cars43.txt
# file name:  Cars136.xml
# /kaggle/input/car-plate-detection/annotations/Cars136.xml
# box:(c,xmin,ymin,xmax,ymax) licence 164 104 245 119
# Dataset/train/labels/Cars136.txt
# file name:  Cars280.xml
# /kaggle/input/car-plate-detection/annotations/Cars280.xml
# box:(c,xmin,ymin,xmax,ymax) licence 191 185 213 195
# Dataset/train/labels/Cars280.txt
# file name:  Cars259.xml
# /kaggle/input/car-plate-detection/annotations/Cars259.xml
# box:(c,xmin,ymin,xmax,ymax) licence 324 166 475 205
# Dataset/train/labels/Cars259.txt
# file name:  Cars407.xml
# /kaggle/input/car-plate-detection/annotations/Cars407.xml
# box:(c,xmin,ymin,xmax,ymax) licence 311 183 346 202
# Dataset/train/labels/Cars407.txt
# file name:  Cars42.xml
# /kaggle/input/car-plate-detection/annotations/Cars42.xml
# box:(c,xmin,ymin,xmax,ymax) licence 177 140 217 159
# Dataset/train/labels/Cars42.txt
# file name:  Cars413.xml
# /kaggle/input/car-plate-detection/annotations/Cars413.xml
# box:(c,xmin,ymin,xmax,ymax) licence 237 143 271 162
# box:(c,xmin,ymin,xmax,ymax) licence 51 170 73 183
# Dataset/train/labels/Cars413.txt
# file name:  Cars365.xml
# /kaggle/input/car-plate-detection/annotations/Cars365.xml
# box:(c,xmin,ymin,xmax,ymax) licence 293 205 373 226
# Dataset/train/labels/Cars365.txt
# file name:  Cars33.xml
# /kaggle/input/car-plate-detection/annotations/Cars33.xml
# box:(c,xmin,ymin,xmax,ymax) licence 94 56 306 169
# Dataset/train/labels/Cars33.txt
# file name:  Cars200.xml
# /kaggle/input/car-plate-detection/annotations/Cars200.xml
# box:(c,xmin,ymin,xmax,ymax) licence 95 189 195 217
# Dataset/train/labels/Cars200.txt
# file name:  Cars279.xml
# /kaggle/input/car-plate-detection/annotations/Cars279.xml
# box:(c,xmin,ymin,xmax,ymax) licence 42 131 202 243
# Dataset/train/labels/Cars279.txt
# file name:  Cars20.xml
# /kaggle/input/car-plate-detection/annotations/Cars20.xml
# box:(c,xmin,ymin,xmax,ymax) licence 18 135 48 152
# Dataset/train/labels/Cars20.txt
# file name:  Cars162.xml
# /kaggle/input/car-plate-detection/annotations/Cars162.xml
# box:(c,xmin,ymin,xmax,ymax) licence 201 168 268 213
# Dataset/train/labels/Cars162.txt
# file name:  Cars126.xml
# /kaggle/input/car-plate-detection/annotations/Cars126.xml
# box:(c,xmin,ymin,xmax,ymax) licence 103 99 293 201
# Dataset/train/labels/Cars126.txt
# file name:  Cars117.xml
# /kaggle/input/car-plate-detection/annotations/Cars117.xml
# box:(c,xmin,ymin,xmax,ymax) licence 42 126 86 137
# Dataset/train/labels/Cars117.txt
# file name:  Cars246.xml
# /kaggle/input/car-plate-detection/annotations/Cars246.xml
# box:(c,xmin,ymin,xmax,ymax) licence 49 163 112 193
# Dataset/train/labels/Cars246.txt
# file name:  Cars8.xml
# /kaggle/input/car-plate-detection/annotations/Cars8.xml
# box:(c,xmin,ymin,xmax,ymax) licence 204 104 304 134
# Dataset/train/labels/Cars8.txt
# file name:  Cars406.xml
# /kaggle/input/car-plate-detection/annotations/Cars406.xml
# box:(c,xmin,ymin,xmax,ymax) licence 285 185 374 226
# Dataset/train/labels/Cars406.txt
# file name:  Cars421.xml
# /kaggle/input/car-plate-detection/annotations/Cars421.xml
# box:(c,xmin,ymin,xmax,ymax) licence 95 162 127 183
# Dataset/train/labels/Cars421.txt
# file name:  Cars34.xml
# /kaggle/input/car-plate-detection/annotations/Cars34.xml
# box:(c,xmin,ymin,xmax,ymax) licence 147 181 260 206
# Dataset/train/labels/Cars34.txt
# file name:  Cars309.xml
# /kaggle/input/car-plate-detection/annotations/Cars309.xml
# box:(c,xmin,ymin,xmax,ymax) licence 152 122 252 207
# Dataset/train/labels/Cars309.txt
# file name:  Cars47.xml
# /kaggle/input/car-plate-detection/annotations/Cars47.xml
# box:(c,xmin,ymin,xmax,ymax) licence 6 143 48 161
# Dataset/train/labels/Cars47.txt
# file name:  Cars220.xml
# /kaggle/input/car-plate-detection/annotations/Cars220.xml
# box:(c,xmin,ymin,xmax,ymax) licence 142 168 188 182
# Dataset/train/labels/Cars220.txt
# file name:  Cars215.xml
# /kaggle/input/car-plate-detection/annotations/Cars215.xml
# box:(c,xmin,ymin,xmax,ymax) licence 92 105 162 123
# Dataset/train/labels/Cars215.txt
# file name:  Cars370.xml
# /kaggle/input/car-plate-detection/annotations/Cars370.xml
# box:(c,xmin,ymin,xmax,ymax) licence 285 249 425 276
# Dataset/train/labels/Cars370.txt
# file name:  Cars103.xml
# /kaggle/input/car-plate-detection/annotations/Cars103.xml
# box:(c,xmin,ymin,xmax,ymax) licence 230 129 248 134
# box:(c,xmin,ymin,xmax,ymax) licence 189 116 202 121
# Dataset/train/labels/Cars103.txt
# file name:  Cars141.xml
# /kaggle/input/car-plate-detection/annotations/Cars141.xml
# box:(c,xmin,ymin,xmax,ymax) licence 266 169 307 188
# Dataset/train/labels/Cars141.txt
# file name:  Cars226.xml
# /kaggle/input/car-plate-detection/annotations/Cars226.xml
# box:(c,xmin,ymin,xmax,ymax) licence 249 194 318 213
# Dataset/train/labels/Cars226.txt
# file name:  Cars225.xml
# /kaggle/input/car-plate-detection/annotations/Cars225.xml
# box:(c,xmin,ymin,xmax,ymax) licence 189 161 384 215
# Dataset/train/labels/Cars225.txt
# file name:  Cars338.xml
# /kaggle/input/car-plate-detection/annotations/Cars338.xml
# box:(c,xmin,ymin,xmax,ymax) licence 297 193 316 205
# Dataset/train/labels/Cars338.txt
# file name:  Cars122.xml
# /kaggle/input/car-plate-detection/annotations/Cars122.xml
# box:(c,xmin,ymin,xmax,ymax) licence 195 147 254 169
# Dataset/train/labels/Cars122.txt
# file name:  Cars80.xml
# /kaggle/input/car-plate-detection/annotations/Cars80.xml
# box:(c,xmin,ymin,xmax,ymax) licence 94 148 279 186
# Dataset/train/labels/Cars80.txt
# file name:  Cars269.xml
# /kaggle/input/car-plate-detection/annotations/Cars269.xml
# box:(c,xmin,ymin,xmax,ymax) licence 110 199 147 217
# Dataset/train/labels/Cars269.txt
# file name:  Cars233.xml
# /kaggle/input/car-plate-detection/annotations/Cars233.xml
# box:(c,xmin,ymin,xmax,ymax) licence 189 55 259 78
# Dataset/train/labels/Cars233.txt
# file name:  Cars366.xml
# /kaggle/input/car-plate-detection/annotations/Cars366.xml
# box:(c,xmin,ymin,xmax,ymax) licence 144 112 316 160
# Dataset/train/labels/Cars366.txt
# file name:  Cars24.xml
# /kaggle/input/car-plate-detection/annotations/Cars24.xml
# box:(c,xmin,ymin,xmax,ymax) licence 167 202 240 221
# Dataset/train/labels/Cars24.txt
# file name:  Cars431.xml
# /kaggle/input/car-plate-detection/annotations/Cars431.xml
# box:(c,xmin,ymin,xmax,ymax) licence 55 82 343 147
# Dataset/train/labels/Cars431.txt
# file name:  Cars55.xml
# /kaggle/input/car-plate-detection/annotations/Cars55.xml
# box:(c,xmin,ymin,xmax,ymax) licence 143 171 210 208
# Dataset/train/labels/Cars55.txt
# file name:  Cars172.xml
# /kaggle/input/car-plate-detection/annotations/Cars172.xml
# box:(c,xmin,ymin,xmax,ymax) licence 173 209 301 239
# Dataset/train/labels/Cars172.txt
# file name:  Cars199.xml
# /kaggle/input/car-plate-detection/annotations/Cars199.xml
# box:(c,xmin,ymin,xmax,ymax) licence 59 88 310 158
# Dataset/train/labels/Cars199.txt
# file name:  Cars304.xml
# /kaggle/input/car-plate-detection/annotations/Cars304.xml
# box:(c,xmin,ymin,xmax,ymax) licence 143 114 222 156
# Dataset/train/labels/Cars304.txt
# file name:  Cars243.xml
# /kaggle/input/car-plate-detection/annotations/Cars243.xml
# box:(c,xmin,ymin,xmax,ymax) licence 129 174 465 235
# Dataset/train/labels/Cars243.txt
# file name:  Cars79.xml
# /kaggle/input/car-plate-detection/annotations/Cars79.xml
# box:(c,xmin,ymin,xmax,ymax) licence 238 363 350 422
# Dataset/train/labels/Cars79.txt
# file name:  Cars177.xml
# /kaggle/input/car-plate-detection/annotations/Cars177.xml
# box:(c,xmin,ymin,xmax,ymax) licence 149 166 272 193
# Dataset/train/labels/Cars177.txt
# file name:  Cars22.xml
# /kaggle/input/car-plate-detection/annotations/Cars22.xml
# box:(c,xmin,ymin,xmax,ymax) licence 207 104 260 116
# Dataset/train/labels/Cars22.txt
# file name:  Cars223.xml
# /kaggle/input/car-plate-detection/annotations/Cars223.xml
# box:(c,xmin,ymin,xmax,ymax) licence 347 231 407 249
# Dataset/train/labels/Cars223.txt
# file name:  Cars331.xml
# /kaggle/input/car-plate-detection/annotations/Cars331.xml
# box:(c,xmin,ymin,xmax,ymax) licence 164 220 235 240
# Dataset/train/labels/Cars331.txt
# file name:  Cars85.xml
# /kaggle/input/car-plate-detection/annotations/Cars85.xml
# box:(c,xmin,ymin,xmax,ymax) licence 86 218 146 235
# box:(c,xmin,ymin,xmax,ymax) licence 313 129 358 141
# Dataset/train/labels/Cars85.txt
# file name:  Cars155.xml
# /kaggle/input/car-plate-detection/annotations/Cars155.xml
# box:(c,xmin,ymin,xmax,ymax) licence 150 177 203 190
# Dataset/train/labels/Cars155.txt
# file name:  Cars222.xml
# /kaggle/input/car-plate-detection/annotations/Cars222.xml
# box:(c,xmin,ymin,xmax,ymax) licence 178 158 235 170
# Dataset/train/labels/Cars222.txt
# file name:  Cars299.xml
# /kaggle/input/car-plate-detection/annotations/Cars299.xml
# box:(c,xmin,ymin,xmax,ymax) licence 101 136 270 176
# Dataset/train/labels/Cars299.txt
# file name:  Cars318.xml
# /kaggle/input/car-plate-detection/annotations/Cars318.xml
# box:(c,xmin,ymin,xmax,ymax) licence 119 117 263 160
# Dataset/train/labels/Cars318.txt
# file name:  Cars4.xml
# /kaggle/input/car-plate-detection/annotations/Cars4.xml
# box:(c,xmin,ymin,xmax,ymax) licence 156 82 503 253
# Dataset/train/labels/Cars4.txt
# file name:  Cars111.xml
# /kaggle/input/car-plate-detection/annotations/Cars111.xml
# box:(c,xmin,ymin,xmax,ymax) licence 319 165 478 204
# Dataset/train/labels/Cars111.txt
# file name:  Cars114.xml
# /kaggle/input/car-plate-detection/annotations/Cars114.xml
# box:(c,xmin,ymin,xmax,ymax) licence 7 16 493 256
# Dataset/train/labels/Cars114.txt
# file name:  Cars66.xml
# /kaggle/input/car-plate-detection/annotations/Cars66.xml
# box:(c,xmin,ymin,xmax,ymax) licence 144 170 211 202
# Dataset/train/labels/Cars66.txt
# file name:  Cars2.xml
# /kaggle/input/car-plate-detection/annotations/Cars2.xml
# box:(c,xmin,ymin,xmax,ymax) licence 229 176 270 193
# Dataset/train/labels/Cars2.txt
# file name:  Cars11.xml
# /kaggle/input/car-plate-detection/annotations/Cars11.xml
# box:(c,xmin,ymin,xmax,ymax) licence 131 206 273 234
# Dataset/train/labels/Cars11.txt
# file name:  Cars379.xml
# /kaggle/input/car-plate-detection/annotations/Cars379.xml
# box:(c,xmin,ymin,xmax,ymax) licence 197 197 351 245
# Dataset/train/labels/Cars379.txt
# file name:  Cars1.xml
# /kaggle/input/car-plate-detection/annotations/Cars1.xml
# box:(c,xmin,ymin,xmax,ymax) licence 134 128 262 160
# Dataset/train/labels/Cars1.txt
# file name:  Cars399.xml
# /kaggle/input/car-plate-detection/annotations/Cars399.xml
# box:(c,xmin,ymin,xmax,ymax) licence 106 62 309 161
# Dataset/train/labels/Cars399.txt
# file name:  Cars82.xml
# /kaggle/input/car-plate-detection/annotations/Cars82.xml
# box:(c,xmin,ymin,xmax,ymax) licence 190 59 257 77
# Dataset/train/labels/Cars82.txt
# file name:  Cars369.xml
# /kaggle/input/car-plate-detection/annotations/Cars369.xml
# box:(c,xmin,ymin,xmax,ymax) licence 176 253 325 280
# Dataset/train/labels/Cars369.txt
# file name:  Cars340.xml
# /kaggle/input/car-plate-detection/annotations/Cars340.xml
# box:(c,xmin,ymin,xmax,ymax) licence 270 126 321 143
# Dataset/train/labels/Cars340.txt
# file name:  Cars166.xml
# /kaggle/input/car-plate-detection/annotations/Cars166.xml
# box:(c,xmin,ymin,xmax,ymax) licence 148 123 201 150
# Dataset/train/labels/Cars166.txt
# file name:  Cars60.xml
# /kaggle/input/car-plate-detection/annotations/Cars60.xml
# box:(c,xmin,ymin,xmax,ymax) licence 45 98 364 159
# Dataset/train/labels/Cars60.txt
# file name:  Cars52.xml
# /kaggle/input/car-plate-detection/annotations/Cars52.xml
# box:(c,xmin,ymin,xmax,ymax) licence 226 181 327 210
# Dataset/train/labels/Cars52.txt
# file name:  Cars297.xml
# /kaggle/input/car-plate-detection/annotations/Cars297.xml
# box:(c,xmin,ymin,xmax,ymax) licence 158 149 247 170
# Dataset/train/labels/Cars297.txt
# file name:  Cars349.xml
# /kaggle/input/car-plate-detection/annotations/Cars349.xml
# box:(c,xmin,ymin,xmax,ymax) licence 38 225 146 249
# Dataset/train/labels/Cars349.txt

# %%
# !mkdir -p Dataset/val/labels
# !cp -rf Dataset/train/labels/Cars1*.txt Dataset/val/labels

# %%
# !ls Dataset/train/labels
# Out:
# Cars0.txt    Cars164.txt  Cars23.txt   Cars296.txt  Cars361.txt  Cars427.txt
# Cars1.txt    Cars165.txt  Cars230.txt  Cars297.txt  Cars362.txt  Cars428.txt
# Cars10.txt   Cars166.txt  Cars231.txt  Cars298.txt  Cars363.txt  Cars429.txt
# Cars100.txt  Cars167.txt  Cars232.txt  Cars299.txt  Cars364.txt  Cars43.txt
# Cars101.txt  Cars168.txt  Cars233.txt  Cars3.txt    Cars365.txt  Cars430.txt
# Cars102.txt  Cars169.txt  Cars234.txt  Cars30.txt   Cars366.txt  Cars431.txt
# Cars103.txt  Cars17.txt   Cars235.txt  Cars300.txt  Cars367.txt  Cars432.txt
# Cars104.txt  Cars170.txt  Cars236.txt  Cars301.txt  Cars368.txt  Cars44.txt
# Cars105.txt  Cars171.txt  Cars237.txt  Cars302.txt  Cars369.txt  Cars45.txt
# Cars106.txt  Cars172.txt  Cars238.txt  Cars303.txt  Cars37.txt	 Cars46.txt
# Cars107.txt  Cars173.txt  Cars239.txt  Cars304.txt  Cars370.txt  Cars47.txt
# Cars108.txt  Cars174.txt  Cars24.txt   Cars305.txt  Cars371.txt  Cars48.txt
# Cars109.txt  Cars175.txt  Cars240.txt  Cars306.txt  Cars372.txt  Cars49.txt
# Cars11.txt   Cars176.txt  Cars241.txt  Cars307.txt  Cars373.txt  Cars5.txt
# Cars110.txt  Cars177.txt  Cars242.txt  Cars308.txt  Cars374.txt  Cars50.txt
# Cars111.txt  Cars178.txt  Cars243.txt  Cars309.txt  Cars375.txt  Cars51.txt
# Cars112.txt  Cars179.txt  Cars244.txt  Cars31.txt   Cars376.txt  Cars52.txt
# Cars113.txt  Cars18.txt   Cars245.txt  Cars310.txt  Cars377.txt  Cars53.txt
# Cars114.txt  Cars180.txt  Cars246.txt  Cars311.txt  Cars378.txt  Cars54.txt
# Cars115.txt  Cars181.txt  Cars247.txt  Cars312.txt  Cars379.txt  Cars55.txt
# Cars116.txt  Cars182.txt  Cars248.txt  Cars313.txt  Cars38.txt	 Cars56.txt
# Cars117.txt  Cars183.txt  Cars249.txt  Cars314.txt  Cars380.txt  Cars57.txt
# Cars118.txt  Cars184.txt  Cars25.txt   Cars315.txt  Cars381.txt  Cars58.txt
# Cars119.txt  Cars185.txt  Cars250.txt  Cars316.txt  Cars382.txt  Cars59.txt
# Cars12.txt   Cars186.txt  Cars251.txt  Cars317.txt  Cars383.txt  Cars6.txt
# Cars120.txt  Cars187.txt  Cars252.txt  Cars318.txt  Cars384.txt  Cars60.txt
# Cars121.txt  Cars188.txt  Cars253.txt  Cars319.txt  Cars385.txt  Cars61.txt
# Cars122.txt  Cars189.txt  Cars254.txt  Cars32.txt   Cars386.txt  Cars62.txt
# Cars123.txt  Cars19.txt   Cars255.txt  Cars320.txt  Cars387.txt  Cars63.txt
# Cars124.txt  Cars190.txt  Cars256.txt  Cars321.txt  Cars388.txt  Cars64.txt
# Cars125.txt  Cars191.txt  Cars257.txt  Cars322.txt  Cars389.txt  Cars65.txt
# Cars126.txt  Cars192.txt  Cars258.txt  Cars323.txt  Cars39.txt	 Cars66.txt
# Cars127.txt  Cars193.txt  Cars259.txt  Cars324.txt  Cars390.txt  Cars67.txt
# Cars128.txt  Cars194.txt  Cars26.txt   Cars325.txt  Cars391.txt  Cars68.txt
# Cars129.txt  Cars195.txt  Cars260.txt  Cars326.txt  Cars392.txt  Cars69.txt
# Cars13.txt   Cars196.txt  Cars261.txt  Cars327.txt  Cars393.txt  Cars7.txt
# Cars130.txt  Cars197.txt  Cars262.txt  Cars328.txt  Cars394.txt  Cars70.txt
# Cars131.txt  Cars198.txt  Cars263.txt  Cars329.txt  Cars395.txt  Cars71.txt
# Cars132.txt  Cars199.txt  Cars264.txt  Cars33.txt   Cars396.txt  Cars72.txt
# Cars133.txt  Cars2.txt	  Cars265.txt  Cars330.txt  Cars397.txt  Cars73.txt
# Cars134.txt  Cars20.txt   Cars266.txt  Cars331.txt  Cars398.txt  Cars74.txt
# Cars135.txt  Cars200.txt  Cars267.txt  Cars332.txt  Cars399.txt  Cars75.txt
# Cars136.txt  Cars201.txt  Cars268.txt  Cars333.txt  Cars4.txt	 Cars76.txt
# Cars137.txt  Cars202.txt  Cars269.txt  Cars334.txt  Cars40.txt	 Cars77.txt
# Cars138.txt  Cars203.txt  Cars27.txt   Cars335.txt  Cars400.txt  Cars78.txt
# Cars139.txt  Cars204.txt  Cars270.txt  Cars336.txt  Cars401.txt  Cars79.txt
# Cars14.txt   Cars205.txt  Cars271.txt  Cars337.txt  Cars402.txt  Cars8.txt
# Cars140.txt  Cars206.txt  Cars272.txt  Cars338.txt  Cars403.txt  Cars80.txt
# Cars141.txt  Cars207.txt  Cars273.txt  Cars339.txt  Cars404.txt  Cars81.txt
# Cars142.txt  Cars208.txt  Cars274.txt  Cars34.txt   Cars405.txt  Cars82.txt
# Cars143.txt  Cars209.txt  Cars275.txt  Cars340.txt  Cars406.txt  Cars83.txt
# Cars144.txt  Cars21.txt   Cars276.txt  Cars341.txt  Cars407.txt  Cars84.txt
# Cars145.txt  Cars210.txt  Cars277.txt  Cars342.txt  Cars408.txt  Cars85.txt
# Cars146.txt  Cars211.txt  Cars278.txt  Cars343.txt  Cars409.txt  Cars86.txt
# Cars147.txt  Cars212.txt  Cars279.txt  Cars344.txt  Cars41.txt	 Cars87.txt
# Cars148.txt  Cars213.txt  Cars28.txt   Cars345.txt  Cars410.txt  Cars88.txt
# Cars149.txt  Cars214.txt  Cars280.txt  Cars346.txt  Cars411.txt  Cars89.txt
# Cars15.txt   Cars215.txt  Cars281.txt  Cars347.txt  Cars412.txt  Cars9.txt
# Cars150.txt  Cars216.txt  Cars282.txt  Cars348.txt  Cars413.txt  Cars90.txt
# Cars151.txt  Cars217.txt  Cars283.txt  Cars349.txt  Cars414.txt  Cars91.txt
# Cars152.txt  Cars218.txt  Cars284.txt  Cars35.txt   Cars415.txt  Cars92.txt
# Cars153.txt  Cars219.txt  Cars285.txt  Cars350.txt  Cars416.txt  Cars93.txt
# Cars154.txt  Cars22.txt   Cars286.txt  Cars351.txt  Cars417.txt  Cars94.txt
# Cars155.txt  Cars220.txt  Cars287.txt  Cars352.txt  Cars418.txt  Cars95.txt
# Cars156.txt  Cars221.txt  Cars288.txt  Cars353.txt  Cars419.txt  Cars96.txt
# Cars157.txt  Cars222.txt  Cars289.txt  Cars354.txt  Cars42.txt	 Cars97.txt
# Cars158.txt  Cars223.txt  Cars29.txt   Cars355.txt  Cars420.txt  Cars98.txt
# Cars159.txt  Cars224.txt  Cars290.txt  Cars356.txt  Cars421.txt  Cars99.txt
# Cars16.txt   Cars225.txt  Cars291.txt  Cars357.txt  Cars422.txt
# Cars160.txt  Cars226.txt  Cars292.txt  Cars358.txt  Cars423.txt
# Cars161.txt  Cars227.txt  Cars293.txt  Cars359.txt  Cars424.txt
# Cars162.txt  Cars228.txt  Cars294.txt  Cars36.txt   Cars425.txt
# Cars163.txt  Cars229.txt  Cars295.txt  Cars360.txt  Cars426.txt

# %% [markdown]
# ## YOLOv5 Training

# %%
import wandb
#Secrets에 있는 Code Snippet 복사해서 붙여넣기
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value = user_secrets.get_secret("wandb")
os.environ["WANDB_API_KEY"] = secret_value
wandb.login()
# Out:
# wandb: Currently logged in as: zzang50aa (use `wandb login --relogin` to force relogin)
# True

# %%
# !python train.py --img 416 --batch 16 --epochs 300 --data data/alpr.yaml --cfg models/yolov5s.yaml --name car_number_plate_yolos_result
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data/alpr.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=car_number_plate_yolos_result, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/rkuo2000/yolov5 ✅
# YOLOv5 🚀 v6.1-303-gb3ca8d8 Python-3.7.10 torch-1.7.0 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# wandb: Currently logged in as: zzang50aa (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.16.5 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.26
# wandb: Syncing run car_number_plate_yolos_result
# wandb: ⭐️ View project at https://wandb.ai/zzang50aa/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/zzang50aa/YOLOv5/runs/ak9sazm3
# wandb: Run data is saved locally in /kaggle/working/yolov5/wandb/run-20240327_032536-ak9sazm3
# wandb: Run `wandb offline` to turn off syncing.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# wandb: Waiting for W&B process to finish, PID 105
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /kaggle/working/yolov5/wandb/run-20240327_032536-ak9sazm3/logs/debug.log
# wandb: Find internal logs for this run at: /kaggle/working/yolov5/wandb/run-20240327_032536-ak9sazm3/logs/debug-internal.log
# wandb: Run summary:
# wandb:             best/epoch 293
# wandb:         best/precision 0.98108
# wandb:            best/recall 0.99096
# wandb:           best/mAP_0.5 0.9931
# wandb:      best/mAP_0.5:0.95 0.82628
# wandb:         train/box_loss 0.01554
# wandb:         train/obj_loss 0.00449
# wandb:         train/cls_loss 0.0
# wandb:      metrics/precision 0.98109
# wandb:         metrics/recall 0.9914
# wandb:        metrics/mAP_0.5 0.99308
# wandb:   metrics/mAP_0.5:0.95 0.82587
# wandb:           val/box_loss 0.01338
# wandb:           val/obj_loss 0.0027
# wandb:           val/cls_loss 0.0
# wandb:                  x/lr0 0.00017
# wandb:                  x/lr1 0.00017
# wandb:                  x/lr2 0.00017
# wandb:               _runtime 6422
# wandb:             _timestamp 1711516358
# wandb:                  _step 300
# wandb: Run history:
# wandb:         train/box_loss █▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/obj_loss █▆▄▃▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         train/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      metrics/precision ▁▅▇▇▇███████████████████████████████████
# wandb:         metrics/recall ▁▅▇▇████████████████████████████████████
# wandb:        metrics/mAP_0.5 ▁▆██████████████████████████████████████
# wandb:   metrics/mAP_0.5:0.95 ▁▄▅▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇█████████████████████
# wandb:           val/box_loss █▅▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           val/obj_loss █▆▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           val/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  x/lr0 ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  x/lr1 ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  x/lr2 ████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:               _runtime ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:             _timestamp ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                  _step ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:
# wandb: Synced 5 W&B file(s), 337 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced car_number_plate_yolos_result: https://wandb.ai/zzang50aa/YOLOv5/runs/ak9sazm3
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f60d0848830>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1144, in _shutdown_workers
# AttributeError: 'NoneType' object has no attribute 'python_exit_status'
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f60d0848830>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1203, in __del__
#   File "/opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1144, in _shutdown_workers
# AttributeError: 'NoneType' object has no attribute 'python_exit_status'

# %% [markdown]
# ## YOLOv5 Detect

# %%
# Download OpenALPR Benchmarks
# %cd ..
# !git clone https://github.com/openalpr/benchmarks
# Out:
# /kaggle/working
# Cloning into 'benchmarks'...
# remote: Enumerating objects: 1752, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 1752 (delta 22), reused 22 (delta 22), pack-reused 1728
# Receiving objects: 100% (1752/1752), 187.98 MiB | 54.45 MiB/s, done.
# Resolving deltas: 100% (35/35), done.

# %%
# %cd yolov5
# Out:
# /kaggle/working/yolov5

# %%
# !python detect.py --source ../benchmarks/endtoend/us --conf 0.4 --weights runs/train/exp/weights/best.pt --save-txt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../benchmarks/endtoend/us, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-303-gb3ca8d8 Python-3.7.10 torch-1.7.0 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 256, in <module>
#     main(opt)
#   File "detect.py", line 251, in main
#     run(**vars(opt))
#   File "/opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 26, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/kaggle/working/yolov5/models/common.py", line 334, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device)
#   File "/kaggle/working/yolov5/models/experimental.py", line 80, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 581, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp/weights/best.pt'

# %%
# !python detect.py --source ../benchmarks/endtoend/eu --conf 0.4 --weights runs/train/exp/weights/best.pt --save-txt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../benchmarks/endtoend/eu, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-303-gb3ca8d8 Python-3.7.10 torch-1.7.0 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 256, in <module>
#     main(opt)
#   File "detect.py", line 251, in main
#     run(**vars(opt))
#   File "/opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 26, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/kaggle/working/yolov5/models/common.py", line 334, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device)
#   File "/kaggle/working/yolov5/models/experimental.py", line 80, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 581, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp/weights/best.pt'

# %%
# !python detect.py --source ../benchmarks/endtoend/br --conf 0.4 --weights runs/train/exp/weights/best.pt --save-txt
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=../benchmarks/endtoend/br, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-303-gb3ca8d8 Python-3.7.10 torch-1.7.0 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "detect.py", line 256, in <module>
#     main(opt)
#   File "detect.py", line 251, in main
#     run(**vars(opt))
#   File "/opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py", line 26, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 92, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/kaggle/working/yolov5/models/common.py", line 334, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device)
#   File "/kaggle/working/yolov5/models/experimental.py", line 80, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 581, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/opt/conda/lib/python3.7/site-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp/weights/best.pt'

# %% [markdown]
# ### Display Detected Images

# %%
from IPython.display import Image

# %%
Image('runs/detect/exp/0b86cecf-67d1-4fc0-87c9-b36b0ee228bb.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp/0b86cecf-67d1-4fc0-87c9-b36b0ee228bb.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp/0b86cecf-67d1-4fc0-87c9-b36b0ee228bb.jpg'

# %%
Image('runs/detect/exp2/test_001.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp2/test_001.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp2/test_001.jpg'

# %%
Image('runs/detect/exp3/PWF3266.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp3/PWF3266.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: 'runs/detect/exp3/PWF3266.jpg'

# %% [markdown]
# ## OCR

# %% [markdown]
# ### get detected ALPR bounding box

# %%
# list saved .txt
# !ls runs/detect/exp/labels

# %%
# read .txt to get x,y,w,h of ALPR
def read_txt(filepath):
    f = open(filepath, 'r')
    lines = f.readlines()
         
    # read objects from each line of .txt
    objects = []
    for line in lines:
        line=line.rstrip()
        obj = [int(float(i)) for i in line.split(' ')]
        objects.append(obj)
    #print(objects)
    return objects

# %% [markdown]
# ### OCR using PyTesseract

# %%
# !pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in /opt/conda/lib/python3.7/site-packages (0.3.7)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from pytesseract) (7.2.0)

# %%
DETECT_PATH = '/kaggle/working/yolov5/runs/detect/exp/'
IMG_NAME    = 'us10'

# %%
Image(DETECT_PATH+IMG_NAME+'.jpg')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_mimebundle_(self, include, exclude)
#    1281         if self.embed:
#    1282             mimetype = self._mimetype
# -> 1283             data, metadata = self._data_and_metadata(always_both=True)
#    1284             if metadata:
#    1285                 metadata = {mimetype: metadata}
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: '/kaggle/working/yolov5/runs/detect/exp/us10.jpg'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1292         try:
# -> 1293             b64_data = b2a_base64(self.data).decode('ascii')
#    1294         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _repr_png_(self)
#    1311     def _repr_png_(self):
#    1312         if self.embed and self.format == self._FMT_PNG:
# -> 1313             return self._data_and_metadata()
#    1314
#    1315     def _repr_jpeg_(self):
#
# /opt/conda/lib/python3.7/site-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1294         except TypeError:
#    1295             raise FileNotFoundError(
# -> 1296                 "No such file or directory: '%s'" % (self.data))
#    1297         md = {}
#    1298         if self.metadata:
#
# FileNotFoundError: No such file or directory: '/kaggle/working/yolov5/runs/detect/exp/us10.jpg'

# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt
img = cv2.imread(DETECT_PATH+IMG_NAME+'.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
lics = read_txt(DETECT_PATH +'labels/'+IMG_NAME+'.txt')

for lic in lics:
    c, x, y, w, h = lic
    print(x,y,w,h) # center of the bounding box
    img_alpr = img[y-int(h/2):y+int(h/2),x-int(w/2):x+int(w/2)]
    plt.imshow(img_alpr)
    txt = pytesseract.image_to_string(img_alpr)
    print(txt)
    
#    img = cv2.putText(img, txt, (x-int(w/2),y-int(h/2)), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)   
#cv2.imwrite('alpr_us1.jpg', img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-28-899bd68de7c6> in <module>
#       3 import matplotlib.pyplot as plt
#       4 img = cv2.imread(DETECT_PATH+IMG_NAME+'.jpg')
# ----> 5 img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       6 lics = read_txt(DETECT_PATH +'labels/'+IMG_NAME+'.txt')
#       7
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-tk9iuyva/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
